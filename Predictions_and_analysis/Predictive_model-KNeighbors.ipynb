# %%
#Libraries import
import pandas as pd
from mordred import Calculator, descriptors
import mordred
import numpy as np
from rdkit import Chem

from sklearn.neighbors import KNeighborsRegressor

from sklearn.metrics import r2_score

from sklearn.decomposition import PCA

import matplotlib.pyplot as plt

# %%
def prepare_data(file):
    
    df = pd.read_excel(file)
    
    try:
        mol_objs = [Chem.MolFromSmiles(smi) for smi in df['SMILES']]
    except:
        mol_objs = [Chem.MolFromSmiles(smi) for smi in df['new_SMILES']]
    
    calculate_descriptors = True
    
    if calculate_descriptors:
        calc = Calculator(descriptors, ignore_3D=True)
        molecular_descriptors = calc.pandas(mol_objs)
        molecular_descriptors = molecular_descriptors.applymap(is_morder_missing)
        molecular_descriptors = molecular_descriptors[sorted(molecular_descriptors.columns)]
    else:
        pass
    print(molecular_descriptors.shape)
    
    simple_preprocessing = True
    if simple_preprocessing:
        molecular_descriptors_cleaned = molecular_descriptors.dropna(axis=1, how='any')
        molecular_descriptors_cleaned
    print(molecular_descriptors_cleaned.shape)
    molecular_descriptors_cleaned = molecular_descriptors_cleaned.loc[:, (molecular_descriptors_cleaned != 0).any(axis=0)]
    print(molecular_descriptors_cleaned.shape)
    
    try:
        molecular_descriptors_cleaned['Aktywność cytoprotekcyjna [%]'] = df['Aktywność cytoprotekcyjna [%]']
    except:
        pass
    
    #try:
        #print('Target distribution histogram: ')
        #print(df['Aktywność cytoprotekcyjna [%]'].hist())
    #except:
        #pass
    
    return molecular_descriptors_cleaned

# %%
def is_morder_missing(x):
    return np.nan if type(x) == mordred.error.Missing or type(x) == mordred.error.Error else x

# %%
def correlation_dataframe(molecular_descriptors_cleaned, correlation_threshold):
    
    correlation_table = pd.DataFrame(data=molecular_descriptors_cleaned.columns.to_list(), columns=["molecular descriptor name"])
    print(correlation_table.head())
    correlation_to_ak_cyt = []
    for mol_desc in correlation_table['molecular descriptor name']:
        x = np.corrcoef(np.array(molecular_descriptors_cleaned[mol_desc]), np.array(molecular_descriptors_cleaned['Aktywność cytoprotekcyjna [%]']))
        x = x.tolist()[0][1]
        correlation_to_ak_cyt.append(x)
    correlation_table['corr_value'] = correlation_to_ak_cyt
    print(correlation_table.head())
    correlation_table['absolute correlation value'] = [abs(x) for x in correlation_table['corr_value']]
    print(correlation_table[:-1].head())
    
    mol_desc_best_corr = correlation_table[correlation_table['absolute correlation value'] > correlation_threshold]
    
    print(mol_desc_best_corr.head())
    table_with_descriptors_to_be_used = mol_desc_best_corr[:-1]
    print(table_with_descriptors_to_be_used.head())
    
    #print("Correlation to the target histogram: ")
    #print(correlation_table['absolute correlation value'][:-1].hist(bins=100))
    
    return table_with_descriptors_to_be_used

# %%
def test_data(molecular_descriptors_cleaned):
    
    test123 = molecular_descriptors_cleaned.loc[(molecular_descriptors_cleaned['Aktywność cytoprotekcyjna [%]'] == 81) 
                                        | (molecular_descriptors_cleaned['Aktywność cytoprotekcyjna [%]'] == 60)
                                       | (molecular_descriptors_cleaned['Aktywność cytoprotekcyjna [%]'] == 28)]
    
    test_data = test123.iloc[[0, 1, 3]] #It allows to get 3 different points of known activity
    
    return test_data

# %%
def prepare_model(data, features, test_data):
    
    X = data[features['molecular descriptor name']]
    
    y = data['Aktywność cytoprotekcyjna [%]']
    
    knr = KNeighborsRegressor()
    
    knr.fit(X, y)
    print("Return the coefficient of determination of the prediction: ")
    print(knr.score(test_data[features['molecular descriptor name']], test_data['Aktywność cytoprotekcyjna [%]']))

    
    pred = knr.predict(X)
    print("R^2 score: "+ str(r2_score(y, pred)))
    sqrt_r2 = np.sqrt(r2_score(y, pred))
    training_data_r2 = r2_score(y, pred)
    print('Correlation coefficient: '+ str(sqrt_r2))
    print("Test data - unseen during training:")
    pred = knr.predict(test_data[features['molecular descriptor name']])
    print("R^2 score: "+ str(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]'])))
    sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
    print('Correlation coefficient: '+ str(sqrt_r2))
    print(pred)
    print(test_data['Aktywność cytoprotekcyjna [%]']) 
    test_data_r2 = r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]'])
    
    return knr, training_data_r2, test_data_r2

# %%
def data_standarization(dataframe):
    
    dataframe_ = dataframe.drop(['Aktywność cytoprotekcyjna [%]'], axis=1)
    
    to_be_returned = (dataframe_ - dataframe_.mean()) / dataframe_.std()
    to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
    
    return to_be_returned

# %%
def prepare_data_and_create_model(molecular_descriptors_df, correlation_threshold, standarization):
    
    if standarization == True:
        
        print("I am doing standarization...")
        
        data_to_be_prepared = molecular_descriptors_df
        
        stand = data_standarization(data_to_be_prepared)
        
        corr = correlation_dataframe(stand, correlation_threshold)
        
        test_ = test_data(stand)
        
        data_to_be_prepared = stand.drop(test_.index.to_list(), axis=0)
        
        model, train_r2, test_r2 = prepare_model(data_to_be_prepared, corr, test_)
        
    elif standarization == False:
        
        print("I am not doing standarization...")
        
        data_to_be_prepared = molecular_descriptors_df
        
        corr = correlation_dataframe(data_to_be_prepared, correlation_threshold)
        
        test_ = test_data(data_to_be_prepared)
        
        data_to_be_prepared = data_to_be_prepared.drop(test_.index.to_list(), axis=0)
        
        model, train_r2, test_r2 = prepare_model(data_to_be_prepared, corr, test_)
    else:
        print("Error...")
    
    return model, train_r2, test_r2, data_to_be_prepared, corr

# %%
molecular_descriptors_df = prepare_data('../Data/Indole_-_cytoprotekcja_.xlsx')
# Out:
#  61%|██████████████████████████████████████████████████▎                               | 27/44 [00:01<00:00, 20.98it/s]
# C:\Users\aleks\anaconda3\envs\cheminf_gpu\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 44/44 [00:01<00:00, 22.94it/s]
# (44, 1613)
# (44, 1433)
# (44, 1182)

# %%
without_standarization, train_r2_, test_r2_, hist1, hist2 = prepare_data_and_create_model(molecular_descriptors_df, 0.3, False)
# Out:
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 468                  BCUTp-1l   -0.321204                    0.321204
# 469                 BCUTpe-1h    0.317690                    0.317690
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 468                  BCUTp-1l   -0.321204                    0.321204
# 469                 BCUTpe-1h    0.317690                    0.317690
# Return the coefficient of determination of the prediction:
# -0.05320074871314917
# R^2 score: 0.23613569802461531
# Correlation coefficient: 0.4859379569704504
# Test data - unseen during training:
# R^2 score: -7.66416445317012
# Correlation coefficient: nan
# [57.9 73.1 56.2]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\393036810.py:22: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))

# %%
print('Target distribution histogram: ')
print(hist1['Aktywność cytoprotekcyjna [%]'].hist())
# Out:
# Target distribution histogram:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
print("Number of features (molecular descriptors used): "+ str(len(hist2)))
# Out:
# Number of features (molecular descriptors used): 21

# %%
hist2
# Out:
#      molecular descriptor name  corr_value  absolute correlation value
# 137                    AATSC3c   -0.319623                    0.319623
# 455                 BCUTare-1h    0.323770                    0.323770
# 456                 BCUTare-1l    0.345707                    0.345707
# 468                   BCUTp-1l   -0.321204                    0.321204
# 469                  BCUTpe-1h    0.317690                    0.317690
# 476                   BCUTv-1l   -0.325136                    0.325136
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 566                     GATS3c    0.308343                    0.308343
# 614                     GATS7c    0.310103                    0.310103
# 706                     MATS3c   -0.317344                    0.317344
# 829                      NaaNH    0.386873                    0.386873
# 831                       NaaS   -0.343855                    0.343855
# 899                      SaaNH    0.359872                    0.359872
# 901                       SaaS   -0.343855                    0.343855
# 913                 SlogP_VSA1    0.338615                    0.338615
# 1030                     VR1_A   -0.339451                    0.339451
# 1040                     VR2_A   -0.339146                    0.339146
# 1126                   n6HRing    0.362058                    0.362058
# 1128                  n6aHRing    0.362527                    0.362527
# 1141                     nBase   -0.312761                    0.312761
# 1160                    nHBDon    0.394681                    0.394681

# %%
with_standarization, train_r2__, test_r2__, hist1_, hist2_ = prepare_data_and_create_model(molecular_descriptors_df, 0.3, True)
# Out:
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 468                  BCUTp-1l   -0.321204                    0.321204
# 469                 BCUTpe-1h    0.317690                    0.317690
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 468                  BCUTp-1l   -0.321204                    0.321204
# 469                 BCUTpe-1h    0.317690                    0.317690
# Return the coefficient of determination of the prediction:
# 0.5022414599906411
# R^2 score: 0.405096383006474
# Correlation coefficient: 0.6364718242047122
# Test data - unseen during training:
# R^2 score: -1.5748832030209878
# Correlation coefficient: nan
# [72.7 70.1 51.2]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\393036810.py:22: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))

# %%
with_standarization.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 5,
#  'p': 2,
#  'weights': 'uniform'}

# %%
with_standarization.predict(molecular_descriptors_df[hist2_['molecular descriptor name']])
# Out:
# array([42.6, 42.6, 42.6, 48.4, 44.4, 48.4, 48.4, 48.4, 48.4, 48.4, 48.4,
#        43. , 44.4, 61.8, 61.8, 61.8, 61.8, 61.8, 61.8, 61.8, 61.8, 44.4,
#        61.8, 56.8, 61.8, 61.8, 61.8, 61.8, 61.8, 61.8, 61.8, 61.8, 61.8,
#        61.8, 61.8, 61.8, 61.8, 67.4, 67.4, 67.4, 67.4, 67.4, 67.4, 56.8])

# %%
xs = r2_score(with_standarization.predict(molecular_descriptors_df[hist2_['molecular descriptor name']]), molecular_descriptors_df['Aktywność cytoprotekcyjna [%]'])

# %%
xs
# Out:
# -11.700819943599361

# %%
print("Number of features (molecular descriptors used): "+ str(len(hist2)))
# Out:
# Number of features (molecular descriptors used): 21

# %%
hist2_
# Out:
#      molecular descriptor name  corr_value  absolute correlation value
# 137                    AATSC3c   -0.319623                    0.319623
# 455                 BCUTare-1h    0.323770                    0.323770
# 456                 BCUTare-1l    0.345707                    0.345707
# 468                   BCUTp-1l   -0.321204                    0.321204
# 469                  BCUTpe-1h    0.317690                    0.317690
# 476                   BCUTv-1l   -0.325136                    0.325136
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 566                     GATS3c    0.308343                    0.308343
# 614                     GATS7c    0.310103                    0.310103
# 706                     MATS3c   -0.317344                    0.317344
# 829                      NaaNH    0.386873                    0.386873
# 831                       NaaS   -0.343855                    0.343855
# 899                      SaaNH    0.359872                    0.359872
# 901                       SaaS   -0.343855                    0.343855
# 913                 SlogP_VSA1    0.338615                    0.338615
# 1030                     VR1_A   -0.339451                    0.339451
# 1040                     VR2_A   -0.339146                    0.339146
# 1126                   n6HRing    0.362058                    0.362058
# 1128                  n6aHRing    0.362527                    0.362527
# 1141                     nBase   -0.312761                    0.312761
# 1160                    nHBDon    0.394681                    0.394681

# %% [markdown]
# ## Search inside correlation space

# %%
step = 0.01
initial_step = 0.25
last_step = 0.4
first_list = [x / 100.0 for x in range(int(initial_step*100), int(last_step*100), int(step*100))]
second_list = []
third_list = []
f_list = []
for i in first_list:
    without_standarization, train_r2, test_r2, _, h_ = prepare_data_and_create_model(molecular_descriptors_df, i, False)
    second_list.append(train_r2)
    third_list.append(test_r2)
    f_list.append(len(h_))
# Out:
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 45                   AATS4are    0.257682                    0.257682
# 53                    AATS4se    0.265626                    0.265626
# 85                     AATS7s    0.254720                    0.254720
# 101                   AATSC0c    0.264307                    0.264307
# 125                   AATSC2c    0.260430                    0.260430
#     molecular descriptor name  corr_value  absolute correlation value
# 45                   AATS4are    0.257682                    0.257682
# 53                    AATS4se    0.265626                    0.265626
# 85                     AATS7s    0.254720                    0.254720
# 101                   AATSC0c    0.264307                    0.264307
# 125                   AATSC2c    0.260430                    0.260430
# Return the coefficient of determination of the prediction:
# -0.6552714085166123
# R^2 score: 0.2514894902060756
# Correlation coefficient: 0.5014872782096028
# Test data - unseen during training:
# R^2 score: -1048.648367952513
# Correlation coefficient: nan
# [75.2 73.1 74.4]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 53                    AATS4se    0.265626                    0.265626
# 101                   AATSC0c    0.264307                    0.264307
# 125                   AATSC2c    0.260430                    0.260430
# 137                   AATSC3c   -0.319623                    0.319623
# 367                    ATSC3c   -0.273000                    0.273000
#     molecular descriptor name  corr_value  absolute correlation value
# 53                    AATS4se    0.265626                    0.265626
# 101                   AATSC0c    0.264307                    0.264307
# 125                   AATSC2c    0.260430                    0.260430
# 137                   AATSC3c   -0.319623                    0.319623
# 367                    ATSC3c   -0.273000                    0.273000
# Return the coefficient of determination of the prediction:
# -0.6552714085166123
# R^2 score: 0.2514894902060756
# Correlation coefficient: 0.5014872782096028
# Test data - unseen during training:
# R^2 score: -1048.648367952513
# Correlation coefficient: nan
# [75.2 73.1 74.4]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\393036810.py:22: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\393036810.py:22: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\393036810.py:22: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 367                    ATSC3c   -0.273000                    0.273000
# 392                    ATSC5d    0.291862                    0.291862
# 401                    ATSC6Z    0.282292                    0.282292
# 407                    ATSC6m    0.277298                    0.277298
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 367                    ATSC3c   -0.273000                    0.273000
# 392                    ATSC5d    0.291862                    0.291862
# 401                    ATSC6Z    0.282292                    0.282292
# 407                    ATSC6m    0.277298                    0.277298
# Return the coefficient of determination of the prediction:
# -0.05626111371080933
# R^2 score: 0.26825855486257677
# Correlation coefficient: 0.5179368251655571
# Test data - unseen during training:
# R^2 score: -21.03680562335252
# Correlation coefficient: nan
# [74.9 73.1 64. ]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 392                    ATSC5d    0.291862                    0.291862
# 401                    ATSC6Z    0.282292                    0.282292
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 392                    ATSC5d    0.291862                    0.291862
# 401                    ATSC6Z    0.282292                    0.282292
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# Return the coefficient of determination of the prediction:
# -0.7808095460926527
# R^2 score: 0.15458100144656017
# Correlation coefficient: 0.3931679049039484
# Test data - unseen during training:
# R^2 score: -17.898495307146057
# Correlation coefficient: nan
# [57.9 73.1 70.8]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 392                    ATSC5d    0.291862                    0.291862
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 461                 BCUTdv-1h    0.298210                    0.298210
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 392                    ATSC5d    0.291862                    0.291862
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 461                 BCUTdv-1h    0.298210                    0.298210
# Return the coefficient of determination of the prediction:
# -0.05320074871314917
# R^2 score: 0.24951424624724328
# Correlation coefficient: 0.4995140100610225
# Test data - unseen during training:
# R^2 score: -7.66416445317012
# Correlation coefficient: nan
# [57.9 73.1 56.2]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\393036810.py:22: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\393036810.py:22: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\393036810.py:22: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 468                  BCUTp-1l   -0.321204                    0.321204
# 469                 BCUTpe-1h    0.317690                    0.317690
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 468                  BCUTp-1l   -0.321204                    0.321204
# 469                 BCUTpe-1h    0.317690                    0.317690
# Return the coefficient of determination of the prediction:
# -0.05320074871314917
# R^2 score: 0.23613569802461531
# Correlation coefficient: 0.4859379569704504
# Test data - unseen during training:
# R^2 score: -7.66416445317012
# Correlation coefficient: nan
# [57.9 73.1 56.2]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 468                  BCUTp-1l   -0.321204                    0.321204
# 469                 BCUTpe-1h    0.317690                    0.317690
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 468                  BCUTp-1l   -0.321204                    0.321204
# 469                 BCUTpe-1h    0.317690                    0.317690
# Return the coefficient of determination of the prediction:
# -0.05320074871314917
# R^2 score: 0.23613569802461531
# Correlation coefficient: 0.4859379569704504
# Test data - unseen during training:
# R^2 score: -7.66416445317012
# Correlation coefficient: nan
# [57.9 73.1 56.2]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 468                  BCUTp-1l   -0.321204                    0.321204
# 476                  BCUTv-1l   -0.325136                    0.325136
# 520            ETA_dEpsilon_D    0.412783                    0.412783
#     molecular descriptor name  corr_value  absolute correlation value
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 468                  BCUTp-1l   -0.321204                    0.321204
# 476                  BCUTv-1l   -0.325136                    0.325136
# 520            ETA_dEpsilon_D    0.412783                    0.412783
# Return the coefficient of determination of the prediction:
# -0.05320074871314917
# R^2 score: 0.23613569802461531
# Correlation coefficient: 0.4859379569704504
# Test data - unseen during training:
# R^2 score: -7.66416445317012
# Correlation coefficient: nan
# [57.9 73.1 56.2]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\393036810.py:22: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\393036810.py:22: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\393036810.py:22: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\393036810.py:22: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 456                BCUTare-1l    0.345707                    0.345707
# 520            ETA_dEpsilon_D    0.412783                    0.412783
# 829                     NaaNH    0.386873                    0.386873
# 831                      NaaS   -0.343855                    0.343855
# 899                     SaaNH    0.359872                    0.359872
#     molecular descriptor name  corr_value  absolute correlation value
# 456                BCUTare-1l    0.345707                    0.345707
# 520            ETA_dEpsilon_D    0.412783                    0.412783
# 829                     NaaNH    0.386873                    0.386873
# 831                      NaaS   -0.343855                    0.343855
# 899                     SaaNH    0.359872                    0.359872
# Return the coefficient of determination of the prediction:
# -0.05320074871314917
# R^2 score: 0.2250918328630036
# Correlation coefficient: 0.4744384394871516
# Test data - unseen during training:
# R^2 score: -7.66416445317012
# Correlation coefficient: nan
# [57.9 73.1 56.2]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 456                BCUTare-1l    0.345707                    0.345707
# 520            ETA_dEpsilon_D    0.412783                    0.412783
# 829                     NaaNH    0.386873                    0.386873
# 831                      NaaS   -0.343855                    0.343855
# 899                     SaaNH    0.359872                    0.359872
#     molecular descriptor name  corr_value  absolute correlation value
# 456                BCUTare-1l    0.345707                    0.345707
# 520            ETA_dEpsilon_D    0.412783                    0.412783
# 829                     NaaNH    0.386873                    0.386873
# 831                      NaaS   -0.343855                    0.343855
# 899                     SaaNH    0.359872                    0.359872
# Return the coefficient of determination of the prediction:
# -0.1518273280299487
# R^2 score: 0.2522107991059782
# Correlation coefficient: 0.5022059329657289
# Test data - unseen during training:
# R^2 score: -20.738541022697184
# Correlation coefficient: nan
# [71.6 59.5 67.4]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#      molecular descriptor name  corr_value  absolute correlation value
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 829                      NaaNH    0.386873                    0.386873
# 899                      SaaNH    0.359872                    0.359872
# 1126                   n6HRing    0.362058                    0.362058
# 1128                  n6aHRing    0.362527                    0.362527
#      molecular descriptor name  corr_value  absolute correlation value
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 829                      NaaNH    0.386873                    0.386873
# 899                      SaaNH    0.359872                    0.359872
# 1126                   n6HRing    0.362058                    0.362058
# 1128                  n6aHRing    0.362527                    0.362527
# Return the coefficient of determination of the prediction:
# -0.1518273280299487
# R^2 score: 0.2588611820887381
# Correlation coefficient: 0.5087840230281785
# Test data - unseen during training:
# R^2 score: -20.738541022697184
# Correlation coefficient: nan
# [71.6 59.5 67.4]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#      molecular descriptor name  corr_value  absolute correlation value
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 829                      NaaNH    0.386873                    0.386873
# 1126                   n6HRing    0.362058                    0.362058
# 1128                  n6aHRing    0.362527                    0.362527
# 1160                    nHBDon    0.394681                    0.394681
#      molecular descriptor name  corr_value  absolute correlation value
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 829                      NaaNH    0.386873                    0.386873
# 1126                   n6HRing    0.362058                    0.362058
# 1128                  n6aHRing    0.362527                    0.362527
# 1160                    nHBDon    0.394681                    0.394681
# Return the coefficient of determination of the prediction:
# 0.6223327094057088
# R^2 score: 0.2769993360051223
# Correlation coefficient: 0.5263072638726567
# Test data - unseen during training:
# R^2 score: -1.1445938405123184
# Correlation coefficient: nan
# [71.6 60.5 49.2]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\393036810.py:22: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\393036810.py:22: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\393036810.py:22: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\393036810.py:22: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#           molecular descriptor name  corr_value  absolute correlation value
# 520                  ETA_dEpsilon_D    0.412783                    0.412783
# 829                           NaaNH    0.386873                    0.386873
# 1160                         nHBDon    0.394681                    0.394681
# 1182  Aktywność cytoprotekcyjna [%]    1.000000                    1.000000
#      molecular descriptor name  corr_value  absolute correlation value
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 829                      NaaNH    0.386873                    0.386873
# 1160                    nHBDon    0.394681                    0.394681
# Return the coefficient of determination of the prediction:
# 0.6788511932615816
# R^2 score: 0.2593901622044631
# Correlation coefficient: 0.5093036051359376
# Test data - unseen during training:
# R^2 score: -0.07067972979297665
# Correlation coefficient: nan
# [78.2 60.5 49.2]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#           molecular descriptor name  corr_value  absolute correlation value
# 520                  ETA_dEpsilon_D    0.412783                    0.412783
# 829                           NaaNH    0.386873                    0.386873
# 1160                         nHBDon    0.394681                    0.394681
# 1182  Aktywność cytoprotekcyjna [%]    1.000000                    1.000000
#      molecular descriptor name  corr_value  absolute correlation value
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 829                      NaaNH    0.386873                    0.386873
# 1160                    nHBDon    0.394681                    0.394681
# Return the coefficient of determination of the prediction:
# 0.6788511932615816
# R^2 score: 0.2593901622044631
# Correlation coefficient: 0.5093036051359376
# Test data - unseen during training:
# R^2 score: -0.07067972979297665
# Correlation coefficient: nan
# [78.2 60.5 49.2]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#           molecular descriptor name  corr_value  absolute correlation value
# 520                  ETA_dEpsilon_D    0.412783                    0.412783
# 1160                         nHBDon    0.394681                    0.394681
# 1182  Aktywność cytoprotekcyjna [%]    1.000000                    1.000000
#      molecular descriptor name  corr_value  absolute correlation value
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 1160                    nHBDon    0.394681                    0.394681
# Return the coefficient of determination of the prediction:
# 0.9212938699110903
# R^2 score: 0.24948021650975838
# Correlation coefficient: 0.49947994605365126
# Test data - unseen during training:
# R^2 score: 0.860452671141385
# Correlation coefficient: 0.9276058813641627
# [78.2 60.5 38.2]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64

# %%
df_without_standarization = pd.DataFrame(data=first_list, columns=["Correlation threshold"])

# %%
df_without_standarization['Training data R^2 score'] = second_list
df_without_standarization['Test data R^2 score'] = third_list
df_without_standarization['Number of features'] = f_list

# %%
df_without_standarization
# Out:
#     Correlation threshold  Training data R^2 score  Test data R^2 score  \
# 0                    0.25                 0.251489         -1048.648368
# 1                    0.26                 0.251489         -1048.648368
# 2                    0.27                 0.268259           -21.036806
# 3                    0.28                 0.154581           -17.898495
# 4                    0.29                 0.249514            -7.664164
# 5                    0.30                 0.236136            -7.664164
# 6                    0.31                 0.236136            -7.664164
# 7                    0.32                 0.236136            -7.664164
# 8                    0.33                 0.225092            -7.664164
# 9                    0.34                 0.252211           -20.738541
# 10                   0.35                 0.258861           -20.738541
# 11                   0.36                 0.276999            -1.144594
# 12                   0.37                 0.259390            -0.070680
# 13                   0.38                 0.259390            -0.070680
# 14                   0.39                 0.249480             0.860453
#
#     Number of features
# 0                   46
# 1                   38
# 2                   30
# 3                   28
# 4                   26
# 5                   21
# 6                   20
# 7                   15
# 8                   12
# 9                    9
# 10                   6
# 11                   5
# 12                   3
# 13                   3
# 14                   2

# %%
step = 0.01
initial_step = 0.25
last_step = 0.4
first_list = [x / 100.0 for x in range(int(initial_step*100), int(last_step*100), int(step*100))]
second_list = []
third_list = []
f_list = []
for i in first_list:
    without_standarization, train_r2, test_r2, _, h_ = prepare_data_and_create_model(molecular_descriptors_df, i, True)
    second_list.append(train_r2)
    third_list.append(test_r2)
    f_list.append(len(h_))
# Out:
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 45                   AATS4are    0.257682                    0.257682
# 53                    AATS4se    0.265626                    0.265626
# 85                     AATS7s    0.254720                    0.254720
# 101                   AATSC0c    0.264307                    0.264307
# 125                   AATSC2c    0.260430                    0.260430
#     molecular descriptor name  corr_value  absolute correlation value
# 45                   AATS4are    0.257682                    0.257682
# 53                    AATS4se    0.265626                    0.265626
# 85                     AATS7s    0.254720                    0.254720
# 101                   AATSC0c    0.264307                    0.264307
# 125                   AATSC2c    0.260430                    0.260430
# Return the coefficient of determination of the prediction:
# -0.3972812353766959
# R^2 score: 0.3511944941781877
# Correlation coefficient: 0.5926166502708035
# Test data - unseen during training:
# R^2 score: -26.877789188684496
# Correlation coefficient: nan
# [74.5 79.5 67.6]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\393036810.py:22: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 53                    AATS4se    0.265626                    0.265626
# 101                   AATSC0c    0.264307                    0.264307
# 125                   AATSC2c    0.260430                    0.260430
# 137                   AATSC3c   -0.319623                    0.319623
# 367                    ATSC3c   -0.273000                    0.273000
#     molecular descriptor name  corr_value  absolute correlation value
# 53                    AATS4se    0.265626                    0.265626
# 101                   AATSC0c    0.264307                    0.264307
# 125                   AATSC2c    0.260430                    0.260430
# 137                   AATSC3c   -0.319623                    0.319623
# 367                    ATSC3c   -0.273000                    0.273000
# Return the coefficient of determination of the prediction:
# -0.3356247075339256
# R^2 score: 0.401550605895326
# Correlation coefficient: 0.633680207908789
# Test data - unseen during training:
# R^2 score: -38.47213386806801
# Correlation coefficient: nan
# [74.5 77.1 67.6]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 367                    ATSC3c   -0.273000                    0.273000
# 392                    ATSC5d    0.291862                    0.291862
# 401                    ATSC6Z    0.282292                    0.282292
# 407                    ATSC6m    0.277298                    0.277298
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 367                    ATSC3c   -0.273000                    0.273000
# 392                    ATSC5d    0.291862                    0.291862
# 401                    ATSC6Z    0.282292                    0.282292
# 407                    ATSC6m    0.277298                    0.277298
# Return the coefficient of determination of the prediction:
# 0.4535844642021525
# R^2 score: 0.39075892539543267
# Correlation coefficient: 0.6251071311346821
# Test data - unseen during training:
# R^2 score: -1.265555577113366
# Correlation coefficient: nan
# [73.5 73.9 51. ]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\393036810.py:22: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\393036810.py:22: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 392                    ATSC5d    0.291862                    0.291862
# 401                    ATSC6Z    0.282292                    0.282292
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 392                    ATSC5d    0.291862                    0.291862
# 401                    ATSC6Z    0.282292                    0.282292
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# Return the coefficient of determination of the prediction:
# 0.4535844642021525
# R^2 score: 0.390729757049017
# Correlation coefficient: 0.6250838000212587
# Test data - unseen during training:
# R^2 score: -1.265555577113366
# Correlation coefficient: nan
# [73.5 73.9 51. ]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 392                    ATSC5d    0.291862                    0.291862
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 461                 BCUTdv-1h    0.298210                    0.298210
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 392                    ATSC5d    0.291862                    0.291862
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 461                 BCUTdv-1h    0.298210                    0.298210
# Return the coefficient of determination of the prediction:
# 0.5158656995788489
# R^2 score: 0.42971355587042614
# Correlation coefficient: 0.655525404443204
# Test data - unseen during training:
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\393036810.py:22: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\393036810.py:22: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
# R^2 score: -1.2045963050565738
# Correlation coefficient: nan
# [74.2 70.7 51. ]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 468                  BCUTp-1l   -0.321204                    0.321204
# 469                 BCUTpe-1h    0.317690                    0.317690
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 468                  BCUTp-1l   -0.321204                    0.321204
# 469                 BCUTpe-1h    0.317690                    0.317690
# Return the coefficient of determination of the prediction:
# 0.5022414599906411
# R^2 score: 0.405096383006474
# Correlation coefficient: 0.6364718242047122
# Test data - unseen during training:
# R^2 score: -1.5748832030209878
# Correlation coefficient: nan
# [72.7 70.1 51.2]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\393036810.py:22: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\393036810.py:22: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 468                  BCUTp-1l   -0.321204                    0.321204
# 469                 BCUTpe-1h    0.317690                    0.317690
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 468                  BCUTp-1l   -0.321204                    0.321204
# 469                 BCUTpe-1h    0.317690                    0.317690
# Return the coefficient of determination of the prediction:
# 0.5200210575573234
# R^2 score: 0.3347614731793498
# Correlation coefficient: 0.578585752658454
# Test data - unseen during training:
# R^2 score: -1.2446003019891898
# Correlation coefficient: nan
# [74.4 70.1 51.2]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 468                  BCUTp-1l   -0.321204                    0.321204
# 476                  BCUTv-1l   -0.325136                    0.325136
# 520            ETA_dEpsilon_D    0.412783                    0.412783
#     molecular descriptor name  corr_value  absolute correlation value
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 468                  BCUTp-1l   -0.321204                    0.321204
# 476                  BCUTv-1l   -0.325136                    0.325136
# 520            ETA_dEpsilon_D    0.412783                    0.412783
# Return the coefficient of determination of the prediction:
# 0.3952480112306972
# R^2 score: 0.38247997640446785
# Correlation coefficient: 0.6184496555132583
# Test data - unseen during training:
# R^2 score: -4.337442696072362
# Correlation coefficient: nan
# [73.6 60.5 56.4]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 456                BCUTare-1l    0.345707                    0.345707
# 520            ETA_dEpsilon_D    0.412783                    0.412783
# 829                     NaaNH    0.386873                    0.386873
# 831                      NaaS   -0.343855                    0.343855
# 899                     SaaNH    0.359872                    0.359872
#     molecular descriptor name  corr_value  absolute correlation value
# 456                BCUTare-1l    0.345707                    0.345707
# 520            ETA_dEpsilon_D    0.412783                    0.412783
# 829                     NaaNH    0.386873                    0.386873
# 831                      NaaS   -0.343855                    0.343855
# 899                     SaaNH    0.359872                    0.359872
# Return the coefficient of determination of the prediction:
# 0.5260014038371548
# R^2 score: 0.2747953028290925
# Correlation coefficient: 0.5242092166579032
# Test data - unseen during training:
# R^2 score: -1.4065358390154685
# Correlation coefficient: nan
# [71.6 69.7 50.2]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\393036810.py:22: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\393036810.py:22: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 456                BCUTare-1l    0.345707                    0.345707
# 520            ETA_dEpsilon_D    0.412783                    0.412783
# 829                     NaaNH    0.386873                    0.386873
# 831                      NaaS   -0.343855                    0.343855
# 899                     SaaNH    0.359872                    0.359872
#     molecular descriptor name  corr_value  absolute correlation value
# 456                BCUTare-1l    0.345707                    0.345707
# 520            ETA_dEpsilon_D    0.412783                    0.412783
# 829                     NaaNH    0.386873                    0.386873
# 831                      NaaS   -0.343855                    0.343855
# 899                     SaaNH    0.359872                    0.359872
# Return the coefficient of determination of the prediction:
# 0.8647753860552174
# R^2 score: 0.22031156625720316
# Correlation coefficient: 0.46937358921993383
# Test data - unseen during training:
# R^2 score: 0.6670909991590148
# Correlation coefficient: 0.8167563891142908
# [71.6 60.5 38.2]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#      molecular descriptor name  corr_value  absolute correlation value
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 829                      NaaNH    0.386873                    0.386873
# 899                      SaaNH    0.359872                    0.359872
# 1126                   n6HRing    0.362058                    0.362058
# 1128                  n6aHRing    0.362527                    0.362527
#      molecular descriptor name  corr_value  absolute correlation value
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 829                      NaaNH    0.386873                    0.386873
# 899                      SaaNH    0.359872                    0.359872
# 1126                   n6HRing    0.362058                    0.362058
# 1128                  n6aHRing    0.362527                    0.362527
# Return the coefficient of determination of the prediction:
# 0.8647753860552174
# R^2 score: 0.21799784794517296
# Correlation coefficient: 0.4669023965939487
# Test data - unseen during training:
# R^2 score: 0.6670909991590148
# Correlation coefficient: 0.8167563891142908
# [71.6 60.5 38.2]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#      molecular descriptor name  corr_value  absolute correlation value
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 829                      NaaNH    0.386873                    0.386873
# 1126                   n6HRing    0.362058                    0.362058
# 1128                  n6aHRing    0.362527                    0.362527
# 1160                    nHBDon    0.394681                    0.394681
#      molecular descriptor name  corr_value  absolute correlation value
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 829                      NaaNH    0.386873                    0.386873
# 1126                   n6HRing    0.362058                    0.362058
# 1128                  n6aHRing    0.362527                    0.362527
# 1160                    nHBDon    0.394681                    0.394681
# Return the coefficient of determination of the prediction:
# 0.8621080954609266
# R^2 score: 0.26231671962816283
# Correlation coefficient: 0.5121686437377466
# Test data - unseen during training:
# R^2 score: 0.6570236390935439
# Correlation coefficient: 0.8105699470702968
# [71.4 60.5 38.2]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#           molecular descriptor name  corr_value  absolute correlation value
# 520                  ETA_dEpsilon_D    0.412783                    0.412783
# 829                           NaaNH    0.386873                    0.386873
# 1160                         nHBDon    0.394681                    0.394681
# 1182  Aktywność cytoprotekcyjna [%]    1.000000                    1.000000
#      molecular descriptor name  corr_value  absolute correlation value
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 829                      NaaNH    0.386873                    0.386873
# 1160                    nHBDon    0.394681                    0.394681
# Return the coefficient of determination of the prediction:
# 0.9212938699110903
# R^2 score: 0.2449518307287344
# Correlation coefficient: 0.49492608612674116
# Test data - unseen during training:
# R^2 score: 0.860452671141385
# Correlation coefficient: 0.9276058813641627
# [78.2 60.5 38.2]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#           molecular descriptor name  corr_value  absolute correlation value
# 520                  ETA_dEpsilon_D    0.412783                    0.412783
# 829                           NaaNH    0.386873                    0.386873
# 1160                         nHBDon    0.394681                    0.394681
# 1182  Aktywność cytoprotekcyjna [%]    1.000000                    1.000000
#      molecular descriptor name  corr_value  absolute correlation value
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 829                      NaaNH    0.386873                    0.386873
# 1160                    nHBDon    0.394681                    0.394681
# Return the coefficient of determination of the prediction:
# 0.9212938699110903
# R^2 score: 0.2449518307287344
# Correlation coefficient: 0.49492608612674116
# Test data - unseen during training:
# R^2 score: 0.860452671141385
# Correlation coefficient: 0.9276058813641627
# [78.2 60.5 38.2]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#           molecular descriptor name  corr_value  absolute correlation value
# 520                  ETA_dEpsilon_D    0.412783                    0.412783
# 1160                         nHBDon    0.394681                    0.394681
# 1182  Aktywność cytoprotekcyjna [%]    1.000000                    1.000000
#      molecular descriptor name  corr_value  absolute correlation value
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 1160                    nHBDon    0.394681                    0.394681
# Return the coefficient of determination of the prediction:
# 0.9212938699110903
# R^2 score: 0.24948021650975838
# Correlation coefficient: 0.49947994605365126
# Test data - unseen during training:
# R^2 score: 0.860452671141385
# Correlation coefficient: 0.9276058813641627
# [78.2 60.5 38.2]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# C:\Users\aleks\AppData\Local\Temp\ipykernel_11968\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']

# %%
df_with_standarization = pd.DataFrame(data=first_list, columns=["Correlation threshold"])
df_with_standarization['Training data R^2 score'] = second_list
df_with_standarization['Test data R^2 score'] = third_list
df_with_standarization['Number of features'] = f_list

# %%
df_with_standarization
# Out:
#     Correlation threshold  Training data R^2 score  Test data R^2 score  \
# 0                    0.25                 0.351194           -26.877789
# 1                    0.26                 0.401551           -38.472134
# 2                    0.27                 0.390759            -1.265556
# 3                    0.28                 0.390730            -1.265556
# 4                    0.29                 0.429714            -1.204596
# 5                    0.30                 0.405096            -1.574883
# 6                    0.31                 0.334761            -1.244600
# 7                    0.32                 0.382480            -4.337443
# 8                    0.33                 0.274795            -1.406536
# 9                    0.34                 0.220312             0.667091
# 10                   0.35                 0.217998             0.667091
# 11                   0.36                 0.262317             0.657024
# 12                   0.37                 0.244952             0.860453
# 13                   0.38                 0.244952             0.860453
# 14                   0.39                 0.249480             0.860453
#
#     Number of features
# 0                   46
# 1                   38
# 2                   30
# 3                   28
# 4                   26
# 5                   21
# 6                   20
# 7                   15
# 8                   12
# 9                    9
# 10                   6
# 11                   5
# 12                   3
# 13                   3
# 14                   2

# %% [markdown]
# ## Plots

# %%
plt.plot(df_without_standarization['Correlation threshold'], df_without_standarization['Training data R^2 score'], label = "Training data R^2 score", marker='v')
plt.plot(df_without_standarization['Correlation threshold'], df_without_standarization['Test data R^2 score'], label = "Test data R^2 score", marker='D')
plt.legend()
plt.xlabel('Correlation threshold')
plt.ylabel('R^2 score')
plt.ylim([0, 1])
plt.show()

# %%
plt.plot(df_without_standarization['Correlation threshold'], df_without_standarization['Number of features'], label = "Number of features", marker='.')
plt.legend()
plt.xlabel('Correlation threshold')
plt.ylabel('Number of features')
plt.show()

# %% [markdown]
# # sqrt(R^2)

# %%
break

# %%
df_without_standarization['train R value'] = [np.sqrt(x) for x in df_without_standarization['Training data R^2 score']]

# %%
df_without_standarization

# %%
xcz = []
for element in df_without_standarization['Test data R^2 score']:
    x = np.sqrt(element)
    try:
        if x > 0:
            xcz.append(x)
        else:
            xcz.append(0)
    except:
        pass

# %%
xcz

# %%
df_without_standarization['test R value'] = xcz

# %%
plt.plot(df_without_standarization['Correlation threshold'], df_without_standarization['train R value'], label = "train R value", marker='v')
plt.plot(df_without_standarization['Correlation threshold'], df_without_standarization['test R value'], label = "test R value", marker='D')
plt.legend()
plt.xlabel('Correlation threshold')
plt.ylabel('R score')
plt.ylim([0, 1])
plt.show()

# %%
plt.plot(df_without_standarization['Correlation threshold'], df_without_standarization['Number of features'], label = "Number of features", marker='.')
plt.legend()
plt.xlabel('Correlation threshold')
plt.ylabel('Number of features')
plt.show()

# %% [markdown]
# ## Final model

# %%
final_model = prepare_data_and_create_model(molecular_descriptors_df, 0.33, False)

# %%
final_model[0].get_params()

# %%
final_model[0].intercept_

# %%
final_model[0].coef_

# %% [markdown]
# ## Build equation

# %%
final_model[4]

# %%
names = list(final_model[4]['molecular descriptor name'])
print("The model's equation is: ")
for i in range(len(names)):
    print(str(final_model[0].coef_[i])+str(' * ')+str(names[i]))
    
print(str(final_model[0].intercept_))

# %% [markdown]
# ## Predict target feature

# %%
to_prediction = prepare_data('../Data/Proposed_structures_with_AI_caffeine_tanimoto_similarity_.xlsx')

# %%
predicted_activity = final_model[0].predict(to_prediction[final_model[4]['molecular descriptor name']])

# %%
smiles = pd.read_excel('../Data/Proposed_structures_with_AI_caffeine_tanimoto_similarity_.xlsx')
smiles = smiles['new_SMILES']
smiles = smiles.to_list()
save_to_df = pd.DataFrame(data=smiles, columns=['SMILES'])

# %%
print(len(smiles))
print(len(predicted_activity))

# %%
save_to_df.head()

# %%
save_to_df['Predicted activity'] = predicted_activity

# %%
save_to_df.head()

# %%
save_to_df.to_excel('../Data/Predicted_activity.xlsx')
