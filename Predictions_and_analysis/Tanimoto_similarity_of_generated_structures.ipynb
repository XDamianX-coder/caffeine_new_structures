# %%
import pandas as pd

# %%
excel = pd.read_excel('../Data/new_structures_caffeine.xlsx')

# %%
excel.head()
# Out:
#    Unnamed: 0                      SMILES_From_Tensor_rotation  CID  \
# 0           0  C=12N(C)C(NCCC/N=C3/SCC(=O)N3)=NC=1N(C(N2C)=O)C    0
# 1           1      C1N(C)C(NCCC/N=C2/SCC(=O)N2)=NCN(C(N1C)=O)C    0
# 2           2      C=12N(C)C(SC(=S)N3CCCC3)=NC=1N(C(=O)N2C)C=O    0
# 3           3       CN(C1)C(NCC=CCCCN=N)C2=C1C(N(C)C(=O)N2C)=O    0
# 4           4    CN(C)C(NCCC/N=C1/SCC(=O)N1)=NC=CC(=O)N(C=O)CC    0
#
#   PUBCHEM_SMILES
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
excel = excel.drop(columns=['Unnamed: 0'])

# %%
excel.head()
# Out:
#                        SMILES_From_Tensor_rotation  CID PUBCHEM_SMILES
# 0  C=12N(C)C(NCCC/N=C3/SCC(=O)N3)=NC=1N(C(N2C)=O)C    0              0
# 1      C1N(C)C(NCCC/N=C2/SCC(=O)N2)=NCN(C(N1C)=O)C    0              0
# 2      C=12N(C)C(SC(=S)N3CCCC3)=NC=1N(C(=O)N2C)C=O    0              0
# 3       CN(C1)C(NCC=CCCCN=N)C2=C1C(N(C)C(=O)N2C)=O    0              0
# 4    CN(C)C(NCCC/N=C1/SCC(=O)N1)=NC=CC(=O)N(C=O)CC    0              0

# %%
excel_1 = excel.copy()

# %%
excel_1.head()
# Out:
#                        SMILES_From_Tensor_rotation  CID PUBCHEM_SMILES
# 0  C=12N(C)C(NCCC/N=C3/SCC(=O)N3)=NC=1N(C(N2C)=O)C    0              0
# 1      C1N(C)C(NCCC/N=C2/SCC(=O)N2)=NCN(C(N1C)=O)C    0              0
# 2      C=12N(C)C(SC(=S)N3CCCC3)=NC=1N(C(=O)N2C)C=O    0              0
# 3       CN(C1)C(NCC=CCCCN=N)C2=C1C(N(C)C(=O)N2C)=O    0              0
# 4    CN(C)C(NCCC/N=C1/SCC(=O)N1)=NC=CC(=O)N(C=O)CC    0              0

# %%
excel_1.drop(index=1)
# Out:
#                           SMILES_From_Tensor_rotation  CID PUBCHEM_SMILES
# 0     C=12N(C)C(NCCC/N=C3/SCC(=O)N3)=NC=1N(C(N2C)=O)C    0              0
# 2         C=12N(C)C(SC(=S)N3CCCC3)=NC=1N(C(=O)N2C)C=O    0              0
# 3          CN(C1)C(NCC=CCCCN=N)C2=C1C(N(C)C(=O)N2C)=O    0              0
# 4       CN(C)C(NCCC/N=C1/SCC(=O)N1)=NC=CC(=O)N(C=O)CC    0              0
# 5    C=12N(C)C(SC3=NC4=CC=CC=C4[NH1]3)C=1N(C)C(N2C)=O    0              0
# ..                                                ...  ...            ...
# 435          C1N(C2)C1(NCC=CCCCN=N)C(N(C)C(=O)N2C=O)C    0              0
# 436        CN(C1)C(NCC=CCCCN=N)C2=C1C(=O)N(C(N2C)=O)C    0              0
# 437          C=1N2CN(C)C(=O)C=1N(C(NCCCCNCCCN)=N2)C=O    0              0
# 438     C=12N(C(N(C)C(=O)C=1NC(NCCCNCCCNCCCN)=N2)C)OC    0              0
# 439     C=1N(C2(N(C)C(=O)C=1NC(NCCCNCCCNCCCN)=N2)C)OC    0              0
#
# [439 rows x 3 columns]

# %%
excel_1.head()
# Out:
#                        SMILES_From_Tensor_rotation  CID PUBCHEM_SMILES
# 0  C=12N(C)C(NCCC/N=C3/SCC(=O)N3)=NC=1N(C(N2C)=O)C    0              0
# 1      C1N(C)C(NCCC/N=C2/SCC(=O)N2)=NCN(C(N1C)=O)C    0              0
# 2      C=12N(C)C(SC(=S)N3CCCC3)=NC=1N(C(=O)N2C)C=O    0              0
# 3       CN(C1)C(NCC=CCCCN=N)C2=C1C(N(C)C(=O)N2C)=O    0              0
# 4    CN(C)C(NCCC/N=C1/SCC(=O)N1)=NC=CC(=O)N(C=O)CC    0              0

# %%
from rdkit import Chem
from rdkit.DataStructs.cDataStructs import TanimotoSimilarity

# %%
new_smils = []
for smiles in excel['SMILES_From_Tensor_rotation']:
    canon = Chem.MolToSmiles(Chem.MolFromSmiles(smiles), canonical=True, isomericSmiles=False)
    new_smils.append(canon)

# %%
len(new_smils)
# Out:
# 440

# %%
data = pd.DataFrame(data=new_smils, columns=['new_SMILES'])
drop_duplicates_smi = data.drop_duplicates(subset=['new_SMILES'])
new_file = drop_duplicates_smi
#drop_duplicates_smi = list(set(new_smils))
new_file.head()
# Out:
#                                     new_SMILES
# 0     Cn1c(NCCCN=C2NC(=O)CS2)nc2c1n(C)c(=O)n2C
# 1      CN1CN=C(NCCCN=C2NC(=O)CS2)N(C)CN(C)C1=O
# 2       Cn1c(SC(=S)N2CCCC2)nc2c1n(C)c(=O)n2C=O
# 3      CN1Cc2c(n(C)c(=O)n(C)c2=O)C1NCC=CCCCN=N
# 4  CCN(C=O)C(=O)C=CN=C(NCCCN=C1NC(=O)CS1)N(C)C

# %%
len(new_file)
# Out:
# 378

# %%
new_file['CID'] = 0
new_file['PUBCHEM_SMILES'] = 0
# Out:
# C:\Users\aleks\AppData\Local\Temp\ipykernel_21124\2792383417.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_file['CID'] = 0
# C:\Users\aleks\AppData\Local\Temp\ipykernel_21124\2792383417.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_file['PUBCHEM_SMILES'] = 0

# %%
read_found_structres = excel_1

# %%
read_found_structres.head()
# Out:
#                        SMILES_From_Tensor_rotation  CID PUBCHEM_SMILES
# 0  C=12N(C)C(NCCC/N=C3/SCC(=O)N3)=NC=1N(C(N2C)=O)C    0              0
# 1      C1N(C)C(NCCC/N=C2/SCC(=O)N2)=NCN(C(N1C)=O)C    0              0
# 2      C=12N(C)C(SC(=S)N3CCCC3)=NC=1N(C(=O)N2C)C=O    0              0
# 3       CN(C1)C(NCC=CCCCN=N)C2=C1C(N(C)C(=O)N2C)=O    0              0
# 4    CN(C)C(NCCC/N=C1/SCC(=O)N1)=NC=CC(=O)N(C=O)CC    0              0

# %%
read_found_structres = read_found_structres.loc[read_found_structres['CID'] > 0]

# %%
read_found_structres.head()
# Out:
#                            SMILES_From_Tensor_rotation        CID  \
# 54   CN1C(SC2=NC3=C(C=CC=C3)[NH1]2)=NC4=C1C(=O)N(C)...     671864
# 56   CN1C(SC2=NC3=C([NH1]2)C=CC=C3)=NC4=C1C(=O)N(C)...     671864
# 63                CN(C)C1=NC=2C(=O)N(C(=O)N(C)C=2N1C)C  121215968
# 123        CN1C(SC(N2CCCC2)=S)=NC3=C1C(N(C)C(N3C)=O)=O  135379403
# 207                    C=12N(C)C=NC=1N(C(=O)N(C)C2=S)C      25768
#
#                                        PUBCHEM_SMILES
# 54   CN1C2=C(N=C1SC3=NC4=CC=CC=C4N3)N(C(=O)N(C2=O)C)C
# 56   CN1C2=C(N=C1SC3=NC4=CC=CC=C4N3)N(C(=O)N(C2=O)C)C
# 63                CN1C2=C(C(=O)N(C(=O)N2C)C)N=C1N(C)C
# 123       CN1C2=C(N=C1SC(=S)N3CCCC3)N(C(=O)N(C2=O)C)C
# 207                      CN1C=NC2=C1C(=S)N(C(=O)N2C)C

# %%
read_found_structres = read_found_structres.reset_index()

# %%
read_found_structres.head()
# Out:
#    index                        SMILES_From_Tensor_rotation        CID  \
# 0     54  CN1C(SC2=NC3=C(C=CC=C3)[NH1]2)=NC4=C1C(=O)N(C)...     671864
# 1     56  CN1C(SC2=NC3=C([NH1]2)C=CC=C3)=NC4=C1C(=O)N(C)...     671864
# 2     63               CN(C)C1=NC=2C(=O)N(C(=O)N(C)C=2N1C)C  121215968
# 3    123        CN1C(SC(N2CCCC2)=S)=NC3=C1C(N(C)C(N3C)=O)=O  135379403
# 4    207                    C=12N(C)C=NC=1N(C(=O)N(C)C2=S)C      25768
#
#                                      PUBCHEM_SMILES
# 0  CN1C2=C(N=C1SC3=NC4=CC=CC=C4N3)N(C(=O)N(C2=O)C)C
# 1  CN1C2=C(N=C1SC3=NC4=CC=CC=C4N3)N(C(=O)N(C2=O)C)C
# 2               CN1C2=C(C(=O)N(C(=O)N2C)C)N=C1N(C)C
# 3       CN1C2=C(N=C1SC(=S)N3CCCC3)N(C(=O)N(C2=O)C)C
# 4                      CN1C=NC2=C1C(=S)N(C(=O)N2C)C

# %%
for r, m in enumerate(read_found_structres['PUBCHEM_SMILES']):
    fingerprint_ = Chem.RDKFingerprint(Chem.MolFromSmiles(m))
    for i, element in enumerate(new_file['new_SMILES']):
        fingerprint_gen_str = Chem.RDKFingerprint(Chem.MolFromSmiles(element))
        sim = TanimotoSimilarity(fingerprint_, fingerprint_gen_str)
        if sim == 1:
            new_file['PUBCHEM_SMILES'][i] = m
            new_file['CID'][i] = read_found_structres['CID'][r]
        else:
            pass
# Out:
# C:\Users\aleks\AppData\Local\Temp\ipykernel_21124\2800160880.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_file['PUBCHEM_SMILES'][i] = m
# C:\Users\aleks\AppData\Local\Temp\ipykernel_21124\2800160880.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_file['CID'][i] = read_found_structres['CID'][r]

# %%
new_file.head()
# Out:
#                                     new_SMILES  CID PUBCHEM_SMILES
# 0     Cn1c(NCCCN=C2NC(=O)CS2)nc2c1n(C)c(=O)n2C    0              0
# 1      CN1CN=C(NCCCN=C2NC(=O)CS2)N(C)CN(C)C1=O    0              0
# 2       Cn1c(SC(=S)N2CCCC2)nc2c1n(C)c(=O)n2C=O    0              0
# 3      CN1Cc2c(n(C)c(=O)n(C)c2=O)C1NCC=CCCCN=N    0              0
# 4  CCN(C=O)C(=O)C=CN=C(NCCCN=C1NC(=O)CS1)N(C)C    0              0

# %% [markdown]
# ## Tanomoto_similarity to initial structures

# %%
smifile = "../Data/initial_caffeine.xlsx"
data = pd.read_excel(smifile)
data = data['SMILES']

initial_structures_new = list(set(data))
print(len(initial_structures_new))
# Out:
# 58

# %%
for element in initial_structures_new:
    new_file[element] = 0

# %%
new_file = new_file.reset_index()
new_file = new_file.drop(columns=['index'])
new_file
# Out:
#                                       new_SMILES  CID PUBCHEM_SMILES  \
# 0       Cn1c(NCCCN=C2NC(=O)CS2)nc2c1n(C)c(=O)n2C    0              0
# 1        CN1CN=C(NCCCN=C2NC(=O)CS2)N(C)CN(C)C1=O    0              0
# 2         Cn1c(SC(=S)N2CCCC2)nc2c1n(C)c(=O)n2C=O    0              0
# 3        CN1Cc2c(n(C)c(=O)n(C)c2=O)C1NCC=CCCCN=N    0              0
# 4    CCN(C=O)C(=O)C=CN=C(NCCCN=C1NC(=O)CS1)N(C)C    0              0
# ..                                           ...  ...            ...
# 373                   CN1CC2NCC=CC3=NC3(C1=O)N2C    0              0
# 374         CC1N(C)C(=O)N(C=O)CN2CC12NCC=CCCCN=N    0              0
# 375        CN1CN2C=C(C1=O)N(C=O)C(NCCCCNCCCN)=N2    0              0
# 376    CON1c2nc(NCCCNCCCNCCCN)[nH]c2C(=O)N(C)C1C    0              0
# 377     CON1C=C2NC(NCCCNCCCNCCCN)=NC1(C)N(C)C2=O    0              0
#
#      CN(C(N1C)=O)C2=C(N(C)C(SCCC)=N2)C1=O  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
# ..                                    ...
# 373                                     0
# 374                                     0
# 375                                     0
# 376                                     0
# 377                                     0
#
#      CN(C(N1C)=O)C2=C(N(C)C(NCCCCCCN)=N2)C1=O  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
# ..                                        ...
# 373                                         0
# 374                                         0
# 375                                         0
# 376                                         0
# 377                                         0
#
#      O=C1C2=C(N=C(NCCCCN3C(CCC3=O)=O)N2C)N(C)C(N1C)=O  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ..                                                ...
# 373                                                 0
# 374                                                 0
# 375                                                 0
# 376                                                 0
# 377                                                 0
#
#      CN(C(C(N(C)C(NCCCNCCCNCCCN)=N1)=C1N2C)=O)C2=O  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                0
# ..                                             ...
# 373                                              0
# 374                                              0
# 375                                              0
# 376                                              0
# 377                                              0
#
#      O=C1C2=C(N=C(NCCCCN3C(C(C=CC=C4)=C4C3=O)=O)N2C)N(C)C(N1C)=O  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 373                                                  0
# 374                                                  0
# 375                                                  0
# 376                                                  0
# 377                                                  0
#
#      O=C1C2=C(N=C(SC3=NC4=C(C=CC=C4)N3CC5=CN(CCCCCN=[N+]=[N-])N=N5)N2C)N(C)C(N1C)=O  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 373                                                  0
# 374                                                  0
# 375                                                  0
# 376                                                  0
# 377                                                  0
#
#      CN(C(C(N(C)C(NCCCNCCCN)=N1)=C1N2C)=O)C2=O  ...  \
# 0                                            0  ...
# 1                                            0  ...
# 2                                            0  ...
# 3                                            0  ...
# 4                                            0  ...
# ..                                         ...  ...
# 373                                          0  ...
# 374                                          0  ...
# 375                                          0  ...
# 376                                          0  ...
# 377                                          0  ...
#
#      CN(C(C(N(C)C(NCCCCNCCCN)=N1)=C1N2C)=O)C2=O  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
# ..                                          ...
# 373                                           0
# 374                                           0
# 375                                           0
# 376                                           0
# 377                                           0
#
#      CN(C(N1C)=O)C2=C(N(C)C(SC(N3CCCC3)=S)=N2)C1=O  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                0
# ..                                             ...
# 373                                              0
# 374                                              0
# 375                                              0
# 376                                              0
# 377                                              0
#
#      O=C1C2=C(N=C(NCCN3C(CCC3=O)=O)N2C)N(C)C(N1C)=O  \
# 0                                                 0
# 1                                                 0
# 2                                                 0
# 3                                                 0
# 4                                                 0
# ..                                              ...
# 373                                               0
# 374                                               0
# 375                                               0
# 376                                               0
# 377                                               0
#
#      CN(C(N1C)=O)C2=C(N(C)C(SCC(C)(C)C)=N2)C1=O  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
# ..                                          ...
# 373                                           0
# 374                                           0
# 375                                           0
# 376                                           0
# 377                                           0
#
#      O=C1C2=C(N=C(SC3=NC4=C(C=CC=C4)N3CC5=CN(CC6=C(CN=[N+]=[N-])C=CC=C6)N=N5)N2C)N(C)C(N1C)=O  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 373                                                  0
# 374                                                  0
# 375                                                  0
# 376                                                  0
# 377                                                  0
#
#      O=C1C2=C(N=C(NCCCCN3C(C=CC3=O)=O)N2C)N(C)C(N1C)=O  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 373                                                  0
# 374                                                  0
# 375                                                  0
# 376                                                  0
# 377                                                  0
#
#      CN(C(N1C)=O)C2=C(N(C)C=N2)C1=O  \
# 0                                 0
# 1                                 0
# 2                                 0
# 3                                 0
# 4                                 0
# ..                              ...
# 373                               0
# 374                               0
# 375                               0
# 376                               0
# 377                               0
#
#      O=C1C2=C(N=C(SC3=NC4=C(C=CC=C4)N3CC5=CN(CCCN=[N+]=[N-])N=N5)N2C)N(C)C(N1C)=O  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 373                                                  0
# 374                                                  0
# 375                                                  0
# 376                                                  0
# 377                                                  0
#
#      CN(C(N1C)=O)C2=C(N(C)C(NCCCN)=N2)C1=O  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
# ..                                     ...
# 373                                      0
# 374                                      0
# 375                                      0
# 376                                      0
# 377                                      0
#
#      CN1C(NCC/N=C2SCC(N/2)=O)=NC3=C1C(N(C)C(N3C)=O)=O
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ..                                                ...
# 373                                                 0
# 374                                                 0
# 375                                                 0
# 376                                                 0
# 377                                                 0
#
# [378 rows x 61 columns]

# %%
for element in initial_structures_new:
    finger_1 = Chem.RDKFingerprint(Chem.MolFromSmiles(element))
    for i, smi in enumerate(new_file['new_SMILES']):
        finger_2 = Chem.RDKFingerprint(Chem.MolFromSmiles(smi))
        ta_sim = TanimotoSimilarity(finger_1, finger_2)
        new_file[element][i] = ta_sim
        if ta_sim == 1:
            new_file[element][i] = 100
# Out:
# C:\Users\aleks\AppData\Local\Temp\ipykernel_21124\1750637079.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_file[element][i] = ta_sim

# %%
new_file.head()
# Out:
#                                     new_SMILES  CID PUBCHEM_SMILES  \
# 0     Cn1c(NCCCN=C2NC(=O)CS2)nc2c1n(C)c(=O)n2C    0              0
# 1      CN1CN=C(NCCCN=C2NC(=O)CS2)N(C)CN(C)C1=O    0              0
# 2       Cn1c(SC(=S)N2CCCC2)nc2c1n(C)c(=O)n2C=O    0              0
# 3      CN1Cc2c(n(C)c(=O)n(C)c2=O)C1NCC=CCCCN=N    0              0
# 4  CCN(C=O)C(=O)C=CN=C(NCCCN=C1NC(=O)CS1)N(C)C    0              0
#
#    CN(C(N1C)=O)C2=C(N(C)C(SCCC)=N2)C1=O  \
# 0                              0.402496
# 1                              0.172633
# 2                              0.504092
# 3                              0.428003
# 4                              0.160032
#
#    CN(C(N1C)=O)C2=C(N(C)C(NCCCCCCN)=N2)C1=O  \
# 0                                  0.537808
# 1                                  0.180302
# 2                                  0.418712
# 3                                  0.428383
# 4                                  0.169781
#
#    O=C1C2=C(N=C(NCCCCN3C(CCC3=O)=O)N2C)N(C)C(N1C)=O  \
# 0                                          0.532088
# 1                                          0.196018
# 2                                          0.427724
# 3                                          0.447028
# 4                                          0.191824
#
#    CN(C(C(N(C)C(NCCCNCCCNCCCN)=N1)=C1N2C)=O)C2=O  \
# 0                                       0.548085
# 1                                       0.187450
# 2                                       0.418002
# 3                                       0.431489
# 4                                       0.176136
#
#    O=C1C2=C(N=C(NCCCCN3C(C(C=CC=C4)=C4C3=O)=O)N2C)N(C)C(N1C)=O  \
# 0                                           0.493402
# 1                                           0.206338
# 2                                           0.410048
# 3                                           0.479579
# 4                                           0.194126
#
#    O=C1C2=C(N=C(SC3=NC4=C(C=CC=C4)N3CC5=CN(CCCCCN=[N+]=[N-])N=N5)N2C)N(C)C(N1C)=O  \
# 0                                           0.399220
# 1                                           0.193991
# 2                                           0.442105
# 3                                           0.491667
# 4                                           0.194370
#
#    CN(C(C(N(C)C(NCCCNCCCN)=N1)=C1N2C)=O)C2=O  ...  \
# 0                                   0.548552  ...
# 1                                   0.186656  ...
# 2                                   0.418321  ...
# 3                                   0.431773  ...
# 4                                   0.176279  ...
#
#    CN(C(C(N(C)C(NCCCCNCCCN)=N1)=C1N2C)=O)C2=O  \
# 0                                    0.541455
# 1                                    0.185127
# 2                                    0.421374
# 3                                    0.430638
# 4                                    0.174757
#
#    CN(C(N1C)=O)C2=C(N(C)C(SC(N3CCCC3)=S)=N2)C1=O  \
# 0                                       0.414381
# 1                                       0.187406
# 2                                       0.616598
# 3                                       0.447217
# 4                                       0.182168
#
#    O=C1C2=C(N=C(NCCN3C(CCC3=O)=O)N2C)N(C)C(N1C)=O  \
# 0                                        0.528226
# 1                                        0.201070
# 2                                        0.423841
# 3                                        0.447233
# 4                                        0.198899
#
#    CN(C(N1C)=O)C2=C(N(C)C(SCC(C)(C)C)=N2)C1=O  \
# 0                                    0.404965
# 1                                    0.172713
# 2                                    0.502435
# 3                                    0.431878
# 4                                    0.162097
#
#    O=C1C2=C(N=C(SC3=NC4=C(C=CC=C4)N3CC5=CN(CC6=C(CN=[N+]=[N-])C=CC=C6)N=N5)N2C)N(C)C(N1C)=O  \
# 0                                           0.392745
# 1                                           0.200631
# 2                                           0.436629
# 3                                           0.497100
# 4                                           0.198838
#
#    O=C1C2=C(N=C(NCCCCN3C(C=CC3=O)=O)N2C)N(C)C(N1C)=O  \
# 0                                           0.528045
# 1                                           0.194717
# 2                                           0.424287
# 3                                           0.453085
# 4                                           0.206436
#
#    CN(C(N1C)=O)C2=C(N(C)C=N2)C1=O  \
# 0                        0.404484
# 1                        0.153203
# 2                        0.403846
# 3                        0.378320
# 4                        0.146692
#
#    O=C1C2=C(N=C(SC3=NC4=C(C=CC=C4)N3CC5=CN(CCCN=[N+]=[N-])N=N5)N2C)N(C)C(N1C)=O  \
# 0                                           0.401307
# 1                                           0.194226
# 2                                           0.437788
# 3                                           0.486905
# 4                                           0.193809
#
#    CN(C(N1C)=O)C2=C(N(C)C(NCCCN)=N2)C1=O  \
# 0                               0.547170
# 1                               0.179283
# 2                               0.414110
# 3                               0.427249
# 4                               0.169657
#
#    CN1C(NCC/N=C2SCC(N/2)=O)=NC3=C1C(N(C)C(N3C)=O)=O
# 0                                          0.605705
# 1                                          0.256917
# 2                                          0.407781
# 3                                          0.444586
# 4                                          0.248181
#
# [5 rows x 61 columns]

# %%
new_file.columns[3:][0]
# Out:
# 'CN(C(N1C)=O)C2=C(N(C)C(SCCC)=N2)C1=O'

# %%
for element in new_file.columns[3:]:
    
    new_file = new_file.drop(new_file[new_file[element] > 99].index)

# %%
new_file.shape
# Out:
# (346, 61)

# %%
new_file.to_excel('../Data/Proposed_structures_with_AI_caffeine_tanimoto_similarity_.xlsx')
