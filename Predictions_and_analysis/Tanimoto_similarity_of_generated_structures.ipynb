# %%
import pandas as pd

# %%
excel = pd.read_excel('../Data/new_structures_caffeine.xlsx')

# %%
excel.head()
# Out:
#    Unnamed: 0                SMILES_From_Tensor_rotation  CID PUBCHEM_SMILES
# 0           0                     CN(C=1SC2=CC=CC=C2)N=1    0              0
# 1           1    CN(CCCCCCNC1)NC2=C(C(N(C)C(N2C)=O)=O)N1    0              0
# 2           2    CN(CCCC1CCNC)NC2=C(C(N(C)C(N2C)=O)=O)N1    0              0
# 3           3  CN(CCC=1CCNC=N)C2=C(C(N(C)C(=O)N2C)=O)N=1    0              0
# 4           4           C1N(CCCCCCNC)NC2=C1CN(C)C(N2C)=O    0              0

# %%
excel = excel.drop(columns=['Unnamed: 0'])

# %%
excel.head()
# Out:
#                  SMILES_From_Tensor_rotation  CID PUBCHEM_SMILES
# 0                     CN(C=1SC2=CC=CC=C2)N=1    0              0
# 1    CN(CCCCCCNC1)NC2=C(C(N(C)C(N2C)=O)=O)N1    0              0
# 2    CN(CCCC1CCNC)NC2=C(C(N(C)C(N2C)=O)=O)N1    0              0
# 3  CN(CCC=1CCNC=N)C2=C(C(N(C)C(=O)N2C)=O)N=1    0              0
# 4           C1N(CCCCCCNC)NC2=C1CN(C)C(N2C)=O    0              0

# %%
excel_1 = excel.copy()

# %%
excel_1.head()
# Out:
#                  SMILES_From_Tensor_rotation  CID PUBCHEM_SMILES
# 0                     CN(C=1SC2=CC=CC=C2)N=1    0              0
# 1    CN(CCCCCCNC1)NC2=C(C(N(C)C(N2C)=O)=O)N1    0              0
# 2    CN(CCCC1CCNC)NC2=C(C(N(C)C(N2C)=O)=O)N1    0              0
# 3  CN(CCC=1CCNC=N)C2=C(C(N(C)C(=O)N2C)=O)N=1    0              0
# 4           C1N(CCCCCCNC)NC2=C1CN(C)C(N2C)=O    0              0

# %%
excel_1.drop(index=1)
# Out:
#                    SMILES_From_Tensor_rotation  CID PUBCHEM_SMILES
# 0                       CN(C=1SC2=CC=CC=C2)N=1    0              0
# 2      CN(CCCC1CCNC)NC2=C(C(N(C)C(N2C)=O)=O)N1    0              0
# 3    CN(CCC=1CCNC=N)C2=C(C(N(C)C(=O)N2C)=O)N=1    0              0
# 4             C1N(CCCCCCNC)NC2=C1CN(C)C(N2C)=O    0              0
# 5               C1N(CCC2CNCNC)C=C2N(C)C(N1C)=O    0              0
# ..                                         ...  ...            ...
# 493     C#1N(CC=CC#1)NC(N(C)C2=O)C(=O)CN(C)C2O    0              0
# 494      C#1N(CC=CC#1)CCC(=O)N(C)C(N(C)C=O)C=O    0              0
# 495     C#1N(CC=CC#1)NC=2N(C)C(N(C(=O)C=2)C)=O    0              0
# 496         C#1N(CC=CC#1)NCN(C(N(C=O)C)=O)CC=O    0              0
# 497        C#1N(CC=CC#1)CCC(=O)N(C)CN(CCCNC)CN    0              0
#
# [497 rows x 3 columns]

# %%
excel_1.head()
# Out:
#                  SMILES_From_Tensor_rotation  CID PUBCHEM_SMILES
# 0                     CN(C=1SC2=CC=CC=C2)N=1    0              0
# 1    CN(CCCCCCNC1)NC2=C(C(N(C)C(N2C)=O)=O)N1    0              0
# 2    CN(CCCC1CCNC)NC2=C(C(N(C)C(N2C)=O)=O)N1    0              0
# 3  CN(CCC=1CCNC=N)C2=C(C(N(C)C(=O)N2C)=O)N=1    0              0
# 4           C1N(CCCCCCNC)NC2=C1CN(C)C(N2C)=O    0              0

# %%
from rdkit import Chem
from rdkit.DataStructs.cDataStructs import TanimotoSimilarity

# %%
new_smils = []
for smiles in excel['SMILES_From_Tensor_rotation']:
    canon = Chem.MolToSmiles(Chem.MolFromSmiles(smiles), canonical=True, isomericSmiles=False)
    new_smils.append(canon)

# %%
len(new_smils)
# Out:
# 498

# %%
data = pd.DataFrame(data=new_smils, columns=['new_SMILES'])
drop_duplicates_smi = data.drop_duplicates(subset=['new_SMILES'])
new_file = drop_duplicates_smi
#drop_duplicates_smi = list(set(new_smils))
new_file.head()
# Out:
#                                new_SMILES
# 0                        CN1N=C1Sc1ccccc1
# 1    CN1CCCCCCNCNc2c(n(C)c(=O)n(C)c2=O)N1
# 2  CNCCC1CCCN(C)Nc2c(c(=O)n(C)c(=O)n2C)N1
# 3   CN1CCC(CCNC=N)=Nc2c1n(C)c(=O)n(C)c2=O
# 4      CNCCCCCCN1CC2=C(N1)N(C)C(=O)N(C)C2

# %%
len(new_file)
# Out:
# 420

# %%
new_file['CID'] = 0
new_file['PUBCHEM_SMILES'] = 0
# Out:
# C:\Users\aleks\AppData\Local\Temp\ipykernel_27048\2792383417.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_file['CID'] = 0
# C:\Users\aleks\AppData\Local\Temp\ipykernel_27048\2792383417.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_file['PUBCHEM_SMILES'] = 0

# %%
read_found_structres = excel_1

# %%
read_found_structres.head()
# Out:
#                  SMILES_From_Tensor_rotation  CID PUBCHEM_SMILES
# 0                     CN(C=1SC2=CC=CC=C2)N=1    0              0
# 1    CN(CCCCCCNC1)NC2=C(C(N(C)C(N2C)=O)=O)N1    0              0
# 2    CN(CCCC1CCNC)NC2=C(C(N(C)C(N2C)=O)=O)N1    0              0
# 3  CN(CCC=1CCNC=N)C2=C(C(N(C)C(=O)N2C)=O)N=1    0              0
# 4           C1N(CCCCCCNC)NC2=C1CN(C)C(N2C)=O    0              0

# %%
read_found_structres = read_found_structres.loc[read_found_structres['CID'] > 0]

# %%
read_found_structres.head()
# Out:
#                            SMILES_From_Tensor_rotation        CID  \
# 31   CN1C(SC2=NC3=C([NH1]2)C=CC=C3)=NC4=C1C(=O)N(C)...     671864
# 239        CN1C(SC(N2CCCC2)=S)=NC3=C1C(N(C)C(N3C)=O)=O  135379403
# 240        CN1C(SC(N2CCCC2)=S)=NC3=C1C(N(C)C(=O)N3C)=O  135379403
# 355         C=12N(C(=O)N(C(C=1NC(SCC(C)(C)C)=N2)=O)C)C   44722449
#
#                                        PUBCHEM_SMILES
# 31   CN1C2=C(N=C1SC3=NC4=CC=CC=C4N3)N(C(=O)N(C2=O)C)C
# 239       CN1C2=C(N=C1SC(=S)N3CCCC3)N(C(=O)N(C2=O)C)C
# 240       CN1C2=C(N=C1SC(=S)N3CCCC3)N(C(=O)N(C2=O)C)C
# 355           CC(C)(C)CSC1=NC2=C(N1)C(=O)N(C(=O)N2C)C

# %%
read_found_structres = read_found_structres.reset_index()

# %%
read_found_structres.head()
# Out:
#    index                        SMILES_From_Tensor_rotation        CID  \
# 0     31  CN1C(SC2=NC3=C([NH1]2)C=CC=C3)=NC4=C1C(=O)N(C)...     671864
# 1    239        CN1C(SC(N2CCCC2)=S)=NC3=C1C(N(C)C(N3C)=O)=O  135379403
# 2    240        CN1C(SC(N2CCCC2)=S)=NC3=C1C(N(C)C(=O)N3C)=O  135379403
# 3    355         C=12N(C(=O)N(C(C=1NC(SCC(C)(C)C)=N2)=O)C)C   44722449
#
#                                      PUBCHEM_SMILES
# 0  CN1C2=C(N=C1SC3=NC4=CC=CC=C4N3)N(C(=O)N(C2=O)C)C
# 1       CN1C2=C(N=C1SC(=S)N3CCCC3)N(C(=O)N(C2=O)C)C
# 2       CN1C2=C(N=C1SC(=S)N3CCCC3)N(C(=O)N(C2=O)C)C
# 3           CC(C)(C)CSC1=NC2=C(N1)C(=O)N(C(=O)N2C)C

# %%
for r, m in enumerate(read_found_structres['PUBCHEM_SMILES']):
    fingerprint_ = Chem.RDKFingerprint(Chem.MolFromSmiles(m))
    for i, element in enumerate(new_file['new_SMILES']):
        fingerprint_gen_str = Chem.RDKFingerprint(Chem.MolFromSmiles(element))
        sim = TanimotoSimilarity(fingerprint_, fingerprint_gen_str)
        if sim == 1:
            new_file['PUBCHEM_SMILES'][i] = m
            new_file['CID'][i] = read_found_structres['CID'][r]
        else:
            pass
# Out:
# C:\Users\aleks\AppData\Local\Temp\ipykernel_27048\2800160880.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_file['PUBCHEM_SMILES'][i] = m
# C:\Users\aleks\AppData\Local\Temp\ipykernel_27048\2800160880.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_file['CID'][i] = read_found_structres['CID'][r]

# %%
new_file.head()
# Out:
#                                new_SMILES  CID PUBCHEM_SMILES
# 0                        CN1N=C1Sc1ccccc1    0              0
# 1    CN1CCCCCCNCNc2c(n(C)c(=O)n(C)c2=O)N1    0              0
# 2  CNCCC1CCCN(C)Nc2c(c(=O)n(C)c(=O)n2C)N1    0              0
# 3   CN1CCC(CCNC=N)=Nc2c1n(C)c(=O)n(C)c2=O    0              0
# 4      CNCCCCCCN1CC2=C(N1)N(C)C(=O)N(C)C2    0              0

# %% [markdown]
# ## Tanomoto_similarity to initial structures

# %%
smifile = "../Data/initial_caffeine.xlsx"
data = pd.read_excel(smifile)
data = data['SMILES']

initial_structures_new = list(set(data))
print(len(initial_structures_new))
# Out:
# 58

# %%
for element in initial_structures_new:
    new_file[element] = 0

# %%
new_file = new_file.reset_index()
new_file = new_file.drop(columns=['index'])
new_file
# Out:
#                                  new_SMILES  CID PUBCHEM_SMILES  \
# 0                          CN1N=C1Sc1ccccc1    0              0
# 1      CN1CCCCCCNCNc2c(n(C)c(=O)n(C)c2=O)N1    0              0
# 2    CNCCC1CCCN(C)Nc2c(c(=O)n(C)c(=O)n2C)N1    0              0
# 3     CN1CCC(CCNC=N)=Nc2c1n(C)c(=O)n(C)c2=O    0              0
# 4        CNCCCCCCN1CC2=C(N1)N(C)C(=O)N(C)C2    0              0
# ..                                      ...  ...            ...
# 415       CN(C=O)C(=O)N(C)C(=O)CCN1C#CC=CC1    0              0
# 416     CN1CC(=O)C(NN2C#CC=CC2)N(C)C(=O)C1O    0              0
# 417      CN(C=O)C(C=O)N(C)C(=O)CCN1C#CC=CC1    0              0
# 418         CN(C=O)C(=O)N(CC=O)CNN1C#CC=CC1    0              0
# 419        CNCCCN(CN)CN(C)C(=O)CCN1C#CC=CC1    0              0
#
#      CN1C(N(C)CCCCCCCCN(C=C(/C=C(C(OC)=O)\S)[N+]([O-])=O)C)=NC2=C1C(N(C)C(N2C)=O)=O  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 415                                                  0
# 416                                                  0
# 417                                                  0
# 418                                                  0
# 419                                                  0
#
#      CN(C(N1C)=O)C2=C(N(C)C(NCCCCN)=N2)C1=O  \
# 0                                         0
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                         0
# ..                                      ...
# 415                                       0
# 416                                       0
# 417                                       0
# 418                                       0
# 419                                       0
#
#      O=C1C2=C(N=C(SC3=NC4=C(C=CC=C4)N3CC5=CN(CCCCCCCCN=[N+]=[N-])N=N5)N2C)N(C)C(N1C)=O  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 415                                                  0
# 416                                                  0
# 417                                                  0
# 418                                                  0
# 419                                                  0
#
#      O=C1C2=C(N=C(SC3=NC4=C(C=CC=C4)N3CC5=CN(CC6=C(CN=[N+]=[N-])C=CC=C6)N=N5)N2C)N(C)C(N1C)=O  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 415                                                  0
# 416                                                  0
# 417                                                  0
# 418                                                  0
# 419                                                  0
#
#      O=C1C2=C(N=C(SC3=NC4=C(C=CC=C4)N3CC5=CN(CC6=CC=C(CN=[N+]=[N-])C=C6)N=N5)N2C)N(C)C(N1C)=O  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 415                                                  0
# 416                                                  0
# 417                                                  0
# 418                                                  0
# 419                                                  0
#
#      O=C1C2=C(N=C(NCCCCN3C(C=CC3=O)=O)N2C)N(C)C(N1C)=O  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 415                                                  0
# 416                                                  0
# 417                                                  0
# 418                                                  0
# 419                                                  0
#
#      CN(C(C(N(C)C(NCCCNCCCCNCCCN)=N1)=C1N2C)=O)C2=O  ...  \
# 0                                                 0  ...
# 1                                                 0  ...
# 2                                                 0  ...
# 3                                                 0  ...
# 4                                                 0  ...
# ..                                              ...  ...
# 415                                               0  ...
# 416                                               0  ...
# 417                                               0  ...
# 418                                               0  ...
# 419                                               0  ...
#
#      CN1C(NCCCC/N=C2SCC(N/2)=O)=NC3=C1C(N(C)C(N3C)=O)=O  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 415                                                  0
# 416                                                  0
# 417                                                  0
# 418                                                  0
# 419                                                  0
#
#      CN1C(NCCC/N=C2SCC(N/2)=O)=NC3=C1C(N(C)C(N3C)=O)=O  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 415                                                  0
# 416                                                  0
# 417                                                  0
# 418                                                  0
# 419                                                  0
#
#      CN1C(SC2=NC3=C(N2)C=CC=C3)=NC2=C1C(=O)N(C)C(=O)N2C  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 415                                                  0
# 416                                                  0
# 417                                                  0
# 418                                                  0
# 419                                                  0
#
#      CN(C(N1C)=S)C2=C(N(C)C=N2)C1=S  \
# 0                                 0
# 1                                 0
# 2                                 0
# 3                                 0
# 4                                 0
# ..                              ...
# 415                               0
# 416                               0
# 417                               0
# 418                               0
# 419                               0
#
#      CN(C(N1C)=O)C2=C(N(C)C(NCCNC(C)=O)=N2)C1=O  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
# ..                                          ...
# 415                                           0
# 416                                           0
# 417                                           0
# 418                                           0
# 419                                           0
#
#      CN1C(N(C)CCN(C=C(/C=C(C(OC)=O)\S)[N+]([O-])=O)C)=NC2=C1C(N(C)C(N2C)=O)=O  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 415                                                  0
# 416                                                  0
# 417                                                  0
# 418                                                  0
# 419                                                  0
#
#      CN(C(N1C)=O)C2=C(N(C)C(NCCN)=N2)C1=O  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
# ..                                    ...
# 415                                     0
# 416                                     0
# 417                                     0
# 418                                     0
# 419                                     0
#
#      CN(C(C(N(C)C(NCCCNCCCNCCCN)=N1)=C1N2C)=O)C2=O  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                0
# ..                                             ...
# 415                                              0
# 416                                              0
# 417                                              0
# 418                                              0
# 419                                              0
#
#      CN(C(N1C)=O)C2=C(N(C)C=N2)C1=O  \
# 0                                 0
# 1                                 0
# 2                                 0
# 3                                 0
# 4                                 0
# ..                              ...
# 415                               0
# 416                               0
# 417                               0
# 418                               0
# 419                               0
#
#      O=C1C2=C(N=C(SC3=NC4=C(C=CC=C4)N3CC5=CN(CCCCCN=[N+]=[N-])N=N5)N2C)N(C)C(N1C)=O
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 415                                                  0
# 416                                                  0
# 417                                                  0
# 418                                                  0
# 419                                                  0
#
# [420 rows x 61 columns]

# %%
for element in initial_structures_new:
    finger_1 = Chem.RDKFingerprint(Chem.MolFromSmiles(element))
    for i, smi in enumerate(new_file['new_SMILES']):
        finger_2 = Chem.RDKFingerprint(Chem.MolFromSmiles(smi))
        ta_sim = TanimotoSimilarity(finger_1, finger_2)
        new_file[element][i] = ta_sim
        if ta_sim == 1:
            new_file[element][i] = 100
# Out:
# C:\Users\aleks\AppData\Local\Temp\ipykernel_27048\1750637079.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_file[element][i] = ta_sim

# %%
new_file.head()
# Out:
#                                new_SMILES  CID PUBCHEM_SMILES  \
# 0                        CN1N=C1Sc1ccccc1    0              0
# 1    CN1CCCCCCNCNc2c(n(C)c(=O)n(C)c2=O)N1    0              0
# 2  CNCCC1CCCN(C)Nc2c(c(=O)n(C)c(=O)n2C)N1    0              0
# 3   CN1CCC(CCNC=N)=Nc2c1n(C)c(=O)n(C)c2=O    0              0
# 4      CNCCCCCCN1CC2=C(N1)N(C)C(=O)N(C)C2    0              0
#
#    CN1C(N(C)CCCCCCCCN(C=C(/C=C(C(OC)=O)\S)[N+]([O-])=O)C)=NC2=C1C(N(C)C(N2C)=O)=O  \
# 0                                           0.103526
# 1                                           0.447923
# 2                                           0.461974
# 3                                           0.479271
# 4                                           0.307278
#
#    CN(C(N1C)=O)C2=C(N(C)C(NCCCCN)=N2)C1=O  \
# 0                                0.100000
# 1                                0.414961
# 2                                0.427091
# 3                                0.436214
# 4                                0.265260
#
#    O=C1C2=C(N=C(SC3=NC4=C(C=CC=C4)N3CC5=CN(CCCCCCCCN=[N+]=[N-])N=N5)N2C)N(C)C(N1C)=O  \
# 0                                           0.097956
# 1                                           0.423472
# 2                                           0.437165
# 3                                           0.458781
# 4                                           0.291906
#
#    O=C1C2=C(N=C(SC3=NC4=C(C=CC=C4)N3CC5=CN(CC6=C(CN=[N+]=[N-])C=CC=C6)N=N5)N2C)N(C)C(N1C)=O  \
# 0                                           0.099865
# 1                                           0.434911
# 2                                           0.454918
# 3                                           0.464182
# 4                                           0.294880
#
#    O=C1C2=C(N=C(SC3=NC4=C(C=CC=C4)N3CC5=CN(CC6=CC=C(CN=[N+]=[N-])C=C6)N=N5)N2C)N(C)C(N1C)=O  \
# 0                                           0.099448
# 1                                           0.425926
# 2                                           0.445363
# 3                                           0.455614
# 4                                           0.293785
#
#    O=C1C2=C(N=C(NCCCCN3C(C=CC3=O)=O)N2C)N(C)C(N1C)=O  \
# 0                                           0.106419
# 1                                           0.428087
# 2                                           0.441411
# 3                                           0.455873
# 4                                           0.291939
#
#    CN(C(C(N(C)C(NCCCNCCCCNCCCN)=N1)=C1N2C)=O)C2=O  ...  \
# 0                                        0.101254  ...
# 1                                        0.420351  ...
# 2                                        0.434274  ...
# 3                                        0.439373  ...
# 4                                        0.275733  ...
#
#    CN1C(NCCCC/N=C2SCC(N/2)=O)=NC3=C1C(N(C)C(N3C)=O)=O  \
# 0                                           0.109908
# 1                                           0.432997
# 2                                           0.449967
# 3                                           0.458553
# 4                                           0.276204
#
#    CN1C(NCCC/N=C2SCC(N/2)=O)=NC3=C1C(N(C)C(N3C)=O)=O  \
# 0                                           0.109349
# 1                                           0.430303
# 2                                           0.445400
# 3                                           0.454008
# 4                                           0.275177
#
#    CN1C(SC2=NC3=C(N2)C=CC=C3)=NC2=C1C(=O)N(C)C(=O)N2C  \
# 0                                           0.107612
# 1                                           0.391627
# 2                                           0.398154
# 3                                           0.409836
# 4                                           0.263656
#
#    CN(C(N1C)=S)C2=C(N(C)C=N2)C1=S  CN(C(N1C)=O)C2=C(N(C)C(NCCNC(C)=O)=N2)C1=O  \
# 0                        0.091011                                    0.101619
# 1                        0.298529                                    0.412587
# 2                        0.305218                                    0.421736
# 3                        0.316537                                    0.429831
# 4                        0.228669                                    0.266069
#
#    CN1C(N(C)CCN(C=C(/C=C(C(OC)=O)\S)[N+]([O-])=O)C)=NC2=C1C(N(C)C(N2C)=O)=O  \
# 0                                           0.101504
# 1                                           0.436745
# 2                                           0.450907
# 3                                           0.460821
# 4                                           0.297987
#
#    CN(C(N1C)=O)C2=C(N(C)C(NCCN)=N2)C1=O  \
# 0                              0.101289
# 1                              0.409059
# 2                              0.418396
# 3                              0.424658
# 4                              0.255656
#
#    CN(C(C(N(C)C(NCCCNCCCNCCCN)=N1)=C1N2C)=O)C2=O  \
# 0                                       0.099910
# 1                                       0.416433
# 2                                       0.429456
# 3                                       0.436562
# 4                                       0.272385
#
#    CN(C(N1C)=O)C2=C(N(C)C=N2)C1=O  \
# 0                        0.101136
# 1                        0.361111
# 2                        0.362211
# 3                        0.366519
# 4                        0.231164
#
#    O=C1C2=C(N=C(SC3=NC4=C(C=CC=C4)N3CC5=CN(CCCCCN=[N+]=[N-])N=N5)N2C)N(C)C(N1C)=O
# 0                                           0.098164
# 1                                           0.423380
# 2                                           0.437090
# 3                                           0.457860
# 4                                           0.290816
#
# [5 rows x 61 columns]

# %%
new_file.columns[3:][0]
# Out:
# 'CN1C(N(C)CCCCCCCCN(C=C(/C=C(C(OC)=O)\\S)[N+]([O-])=O)C)=NC2=C1C(N(C)C(N2C)=O)=O'

# %%
for element in new_file.columns[3:]:
    
    new_file = new_file.drop(new_file[new_file[element] > 99].index)

# %%
new_file.shape
# Out:
# (383, 61)

# %%
new_file.to_excel('../Data/Proposed_structures_with_AI_caffeine_tanimoto_similarity_.xlsx')
