# %%
#Libraries import
import pandas as pd
from mordred import Calculator, descriptors
import mordred
import numpy as np
from rdkit import Chem

from sklearn.svm import SVR

from sklearn.metrics import r2_score

from sklearn.decomposition import PCA

import matplotlib.pyplot as plt

# %%
def prepare_data(file):
    
    df = pd.read_excel(file)
    
    try:
        mol_objs = [Chem.MolFromSmiles(smi) for smi in df['SMILES']]
    except:
        mol_objs = [Chem.MolFromSmiles(smi) for smi in df['new_SMILES']]
    
    calculate_descriptors = True
    
    if calculate_descriptors:
        calc = Calculator(descriptors, ignore_3D=True)
        molecular_descriptors = calc.pandas(mol_objs)
        molecular_descriptors = molecular_descriptors.applymap(is_morder_missing)
        molecular_descriptors = molecular_descriptors[sorted(molecular_descriptors.columns)]
    else:
        pass
    print(molecular_descriptors.shape)
    
    simple_preprocessing = True
    if simple_preprocessing:
        molecular_descriptors_cleaned = molecular_descriptors.dropna(axis=1, how='any')
        molecular_descriptors_cleaned
    print(molecular_descriptors_cleaned.shape)
    molecular_descriptors_cleaned = molecular_descriptors_cleaned.loc[:, (molecular_descriptors_cleaned != 0).any(axis=0)]
    print(molecular_descriptors_cleaned.shape)
    
    try:
        molecular_descriptors_cleaned['Aktywność cytoprotekcyjna [%]'] = df['Aktywność cytoprotekcyjna [%]']
    except:
        pass
    
    #try:
        #print('Target distribution histogram: ')
        #print(df['Aktywność cytoprotekcyjna [%]'].hist())
    #except:
        #pass
    
    return molecular_descriptors_cleaned

# %%
def is_morder_missing(x):
    return np.nan if type(x) == mordred.error.Missing or type(x) == mordred.error.Error else x

# %%
def correlation_dataframe(molecular_descriptors_cleaned, correlation_threshold):
    
    correlation_table = pd.DataFrame(data=molecular_descriptors_cleaned.columns.to_list(), columns=["molecular descriptor name"])
    print(correlation_table.head())
    correlation_to_ak_cyt = []
    for mol_desc in correlation_table['molecular descriptor name']:
        x = np.corrcoef(np.array(molecular_descriptors_cleaned[mol_desc]), np.array(molecular_descriptors_cleaned['Aktywność cytoprotekcyjna [%]']))
        x = x.tolist()[0][1]
        correlation_to_ak_cyt.append(x)
    correlation_table['corr_value'] = correlation_to_ak_cyt
    print(correlation_table.head())
    correlation_table['absolute correlation value'] = [abs(x) for x in correlation_table['corr_value']]
    print(correlation_table[:-1].head())
    
    mol_desc_best_corr = correlation_table[correlation_table['absolute correlation value'] > correlation_threshold]
    
    print(mol_desc_best_corr.head())
    table_with_descriptors_to_be_used = mol_desc_best_corr[:-1]
    print(table_with_descriptors_to_be_used.head())
    
    #print("Correlation to the target histogram: ")
    #print(correlation_table['absolute correlation value'][:-1].hist(bins=100))
    
    return table_with_descriptors_to_be_used

# %%
def test_data(molecular_descriptors_cleaned):
    
    test123 = molecular_descriptors_cleaned.loc[(molecular_descriptors_cleaned['Aktywność cytoprotekcyjna [%]'] == 81) 
                                        | (molecular_descriptors_cleaned['Aktywność cytoprotekcyjna [%]'] == 60)
                                       | (molecular_descriptors_cleaned['Aktywność cytoprotekcyjna [%]'] == 28)]
    
    test_data = test123.iloc[[0, 1, 3]] #It allows to get 3 different points of known activity
    
    return test_data

# %%
def prepare_model(data, features, test_data):
    
    X = data[features['molecular descriptor name']]
    
    y = data['Aktywność cytoprotekcyjna [%]']
    
    #regr = linear_model.LinearRegression()
    
    svr = SVR(gamma='auto')
    
    svr.fit(X, y)
    print("Return the coefficient of determination of the prediction: ")
    print(svr.score(test_data[features['molecular descriptor name']], test_data['Aktywność cytoprotekcyjna [%]']))
    
    pred = svr.predict(X)
    print("R^2 score: "+ str(r2_score(y, pred)))
    sqrt_r2 = np.sqrt(r2_score(y, pred))
    training_data_r2 = r2_score(y, pred)
    print('Correlation coefficient: '+ str(sqrt_r2))
    print("Test data - unseen during training:")
    pred = svr.predict(test_data[features['molecular descriptor name']])
    print("R^2 score: "+ str(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]'])))
    sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
    print('Correlation coefficient: '+ str(sqrt_r2))
    print(pred)
    print(test_data['Aktywność cytoprotekcyjna [%]']) 
    test_data_r2 = r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]'])

    return svr, training_data_r2, test_data_r2

# %%
def data_standarization(dataframe):
    
    dataframe_ = dataframe.drop(['Aktywność cytoprotekcyjna [%]'], axis=1)
    
    to_be_returned = (dataframe_ - dataframe_.mean()) / dataframe_.std()
    to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
    
    return to_be_returned

# %%
def prepare_data_and_create_model(molecular_descriptors_df, correlation_threshold, standarization):
    
    if standarization == True:
        
        print("I am doing standarization...")
        
        data_to_be_prepared = molecular_descriptors_df
        
        stand = data_standarization(data_to_be_prepared)
        
        corr = correlation_dataframe(stand, correlation_threshold)
        
        test_ = test_data(stand)
        
        data_to_be_prepared = stand.drop(test_.index.to_list(), axis=0)
        
        model, train_r2, test_r2 = prepare_model(data_to_be_prepared, corr, test_)
        
    elif standarization == False:
        
        print("I am not doing standarization...")
        
        data_to_be_prepared = molecular_descriptors_df
        
        corr = correlation_dataframe(data_to_be_prepared, correlation_threshold)
        
        test_ = test_data(data_to_be_prepared)
        
        data_to_be_prepared = data_to_be_prepared.drop(test_.index.to_list(), axis=0)
        
        model, train_r2, test_r2 = prepare_model(data_to_be_prepared, corr, test_)
    else:
        print("Error...")
    
    return model, train_r2, test_r2, data_to_be_prepared, corr

# %%
molecular_descriptors_df = prepare_data('../Data/initial_caffeine.xlsx')
# Out:
#  61%|██████████████████████████████████████████████████▎                               | 27/44 [00:01<00:00, 27.19it/s]
# C:\Users\aleks\anaconda3\envs\cheminf_gpu\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 44/44 [00:01<00:00, 22.42it/s]
# (44, 1613)
# (44, 1433)
# (44, 1182)

# %%
without_standarization, train_r2_, test_r2_, hist1, hist2 = prepare_data_and_create_model(molecular_descriptors_df, 0.33, False)
# Out:
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 456                BCUTare-1l    0.345707                    0.345707
# 520            ETA_dEpsilon_D    0.412783                    0.412783
# 829                     NaaNH    0.386873                    0.386873
# 831                      NaaS   -0.343855                    0.343855
# 899                     SaaNH    0.359872                    0.359872
#     molecular descriptor name  corr_value  absolute correlation value
# 456                BCUTare-1l    0.345707                    0.345707
# 520            ETA_dEpsilon_D    0.412783                    0.412783
# 829                     NaaNH    0.386873                    0.386873
# 831                      NaaS   -0.343855                    0.343855
# 899                     SaaNH    0.359872                    0.359872
# Return the coefficient of determination of the prediction:
# -0.609085190282078
# R^2 score: -0.04796942153222039
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: -46795.75579413227
# Correlation coefficient: nan
# [73.09857524 73.09857524 73.36964677]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:23: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))

# %%
print('Target distribution histogram: ')
print(hist1['Aktywność cytoprotekcyjna [%]'].hist())
# Out:
# Target distribution histogram:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
print("Number of features (molecular descriptors used): "+ str(len(hist2)))
# Out:
# Number of features (molecular descriptors used): 12

# %%
hist2
# Out:
#      molecular descriptor name  corr_value  absolute correlation value
# 456                 BCUTare-1l    0.345707                    0.345707
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 829                      NaaNH    0.386873                    0.386873
# 831                       NaaS   -0.343855                    0.343855
# 899                      SaaNH    0.359872                    0.359872
# 901                       SaaS   -0.343855                    0.343855
# 913                 SlogP_VSA1    0.338615                    0.338615
# 1030                     VR1_A   -0.339451                    0.339451
# 1040                     VR2_A   -0.339146                    0.339146
# 1126                   n6HRing    0.362058                    0.362058
# 1128                  n6aHRing    0.362527                    0.362527
# 1160                    nHBDon    0.394681                    0.394681

# %%
xs = r2_score(without_standarization.predict(molecular_descriptors_df[hist2['molecular descriptor name']]), molecular_descriptors_df['Aktywność cytoprotekcyjna [%]'])

# %%
xs
# Out:
# -454.8583613275499

# %%
np.sqrt(xs)
# Out:
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3090881320.py:1: RuntimeWarning: invalid value encountered in sqrt
#   np.sqrt(xs)
# nan

# %%
with_standarization, train_r2__, test_r2__, hist1_, hist2_ = prepare_data_and_create_model(molecular_descriptors_df, 0.33, True)
# Out:
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 456                BCUTare-1l    0.345707                    0.345707
# 520            ETA_dEpsilon_D    0.412783                    0.412783
# 829                     NaaNH    0.386873                    0.386873
# 831                      NaaS   -0.343855                    0.343855
# 899                     SaaNH    0.359872                    0.359872
#     molecular descriptor name  corr_value  absolute correlation value
# 456                BCUTare-1l    0.345707                    0.345707
# 520            ETA_dEpsilon_D    0.412783                    0.412783
# 829                     NaaNH    0.386873                    0.386873
# 831                      NaaS   -0.343855                    0.343855
# 899                     SaaNH    0.359872                    0.359872
# Return the coefficient of determination of the prediction:
# -0.4077083979488305
# R^2 score: -0.05012335560264036
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: -1428.9241300113017
# Correlation coefficient: nan
# [71.79542063 71.60985385 70.26111976]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:23: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))

# %%
with_standarization.get_params()
# Out:
# {'C': 1.0,
#  'cache_size': 200,
#  'coef0': 0.0,
#  'degree': 3,
#  'epsilon': 0.1,
#  'gamma': 'auto',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
with_standarization.predict(molecular_descriptors_df[hist2_['molecular descriptor name']])
# Out:
# array([72.56719145, 72.56719145, 72.56719145, 72.56719145, 72.56719145,
#        72.56719145, 72.56719145, 72.56719145, 72.56719145, 72.56719145,
#        72.56719145, 72.56719145, 72.56719145, 72.56719145, 72.56719145,
#        72.56719145, 72.56719145, 72.56719145, 72.56719145, 72.56719145,
#        72.56719145, 72.56719145, 72.56719145, 72.56719145, 72.56719145,
#        72.56719145, 72.56719145, 72.56719145, 72.56719145, 72.56719145,
#        72.56719145, 72.56719145, 72.56719145, 72.56719145, 72.56719145,
#        72.56719145, 72.56719145, 72.56719145, 72.56719145, 72.56719145,
#        72.56719145, 72.56719145, 72.56719145, 72.56719145])

# %%
xs = r2_score(with_standarization.predict(molecular_descriptors_df[hist2_['molecular descriptor name']]), molecular_descriptors_df['Aktywność cytoprotekcyjna [%]'])

# %%
xs
# Out:
# 0.0

# %%
print('Target distribution histogram: ')
print(hist1_['Aktywność cytoprotekcyjna [%]'].hist())
# Out:
# Target distribution histogram:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
print("Number of features (molecular descriptors used): "+ str(len(hist2)))
# Out:
# Number of features (molecular descriptors used): 12

# %%
hist2_
# Out:
#      molecular descriptor name  corr_value  absolute correlation value
# 456                 BCUTare-1l    0.345707                    0.345707
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 829                      NaaNH    0.386873                    0.386873
# 831                       NaaS   -0.343855                    0.343855
# 899                      SaaNH    0.359872                    0.359872
# 901                       SaaS   -0.343855                    0.343855
# 913                 SlogP_VSA1    0.338615                    0.338615
# 1030                     VR1_A   -0.339451                    0.339451
# 1040                     VR2_A   -0.339146                    0.339146
# 1126                   n6HRing    0.362058                    0.362058
# 1128                  n6aHRing    0.362527                    0.362527
# 1160                    nHBDon    0.394681                    0.394681

# %% [markdown]
# ## Search inside correlation space

# %%
step = 0.01
initial_step = 0.25
last_step = 0.4
first_list = [x / 100.0 for x in range(int(initial_step*100), int(last_step*100), int(step*100))]
second_list = []
third_list = []
f_list = []
for i in first_list:
    without_standarization, train_r2, test_r2, _, h_ = prepare_data_and_create_model(molecular_descriptors_df, i, False)
    second_list.append(train_r2)
    third_list.append(test_r2)
    f_list.append(len(h_))
# Out:
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 45                   AATS4are    0.257682                    0.257682
# 53                    AATS4se    0.265626                    0.265626
# 85                     AATS7s    0.254720                    0.254720
# 101                   AATSC0c    0.264307                    0.264307
# 125                   AATSC2c    0.260430                    0.260430
#     molecular descriptor name  corr_value  absolute correlation value
# 45                   AATS4are    0.257682                    0.257682
# 53                    AATS4se    0.265626                    0.265626
# 85                     AATS7s    0.254720                    0.254720
# 101                   AATSC0c    0.264307                    0.264307
# 125                   AATSC2c    0.260430                    0.260430
# Return the coefficient of determination of the prediction:
# -0.59197239120262
# R^2 score: -0.06107638312504471
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: 0.0
# Correlation coefficient: 0.0
# [73.1 73.1 73.1]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 53                    AATS4se    0.265626                    0.265626
# 101                   AATSC0c    0.264307                    0.264307
# 125                   AATSC2c    0.260430                    0.260430
# 137                   AATSC3c   -0.319623                    0.319623
# 367                    ATSC3c   -0.273000                    0.273000
#     molecular descriptor name  corr_value  absolute correlation value
# 53                    AATS4se    0.265626                    0.265626
# 101                   AATSC0c    0.264307                    0.264307
# 125                   AATSC2c    0.260430                    0.260430
# 137                   AATSC3c   -0.319623                    0.319623
# 367                    ATSC3c   -0.273000                    0.273000
# Return the coefficient of determination of the prediction:
# -0.59197239120262
# R^2 score: -0.06107638312504471
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: 0.0
# Correlation coefficient: 0.0
# [73.1 73.1 73.1]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 367                    ATSC3c   -0.273000                    0.273000
# 392                    ATSC5d    0.291862                    0.291862
# 401                    ATSC6Z    0.282292                    0.282292
# 407                    ATSC6m    0.277298                    0.277298
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 367                    ATSC3c   -0.273000                    0.273000
# 392                    ATSC5d    0.291862                    0.291862
# 401                    ATSC6Z    0.282292                    0.282292
# 407                    ATSC6m    0.277298                    0.277298
# Return the coefficient of determination of the prediction:
# -0.59197239120262
# R^2 score: -0.061055105921605346
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: 0.0
# Correlation coefficient: 0.0
# [73.1 73.1 73.1]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 392                    ATSC5d    0.291862                    0.291862
# 401                    ATSC6Z    0.282292                    0.282292
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 392                    ATSC5d    0.291862                    0.291862
# 401                    ATSC6Z    0.282292                    0.282292
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# Return the coefficient of determination of the prediction:
# -0.5919723893816751
# R^2 score: -0.058329000934228326
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: 0.0
# Correlation coefficient: 0.0
# [73.09999997 73.09999997 73.09999997]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 392                    ATSC5d    0.291862                    0.291862
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 461                 BCUTdv-1h    0.298210                    0.298210
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 392                    ATSC5d    0.291862                    0.291862
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 461                 BCUTdv-1h    0.298210                    0.298210
# Return the coefficient of determination of the prediction:
# -0.6001864997991253
# R^2 score: -0.04862845154850626
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: -177537.24201475366
# Correlation coefficient: nan
# [73.09171788 73.09171788 73.23050258]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 468                  BCUTp-1l   -0.321204                    0.321204
# 469                 BCUTpe-1h    0.317690                    0.317690
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 468                  BCUTp-1l   -0.321204                    0.321204
# 469                 BCUTpe-1h    0.317690                    0.317690
# Return the coefficient of determination of the prediction:
# -0.6168427372277974
# R^2 score: -0.04873762255515812
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: -20292.407956776104
# Correlation coefficient: nan
# [73.08069051 73.08069051 73.49331848]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 468                  BCUTp-1l   -0.321204                    0.321204
# 469                 BCUTpe-1h    0.317690                    0.317690
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 468                  BCUTp-1l   -0.321204                    0.321204
# 469                 BCUTpe-1h    0.317690                    0.317690
# Return the coefficient of determination of the prediction:
# -0.6166825949700767
# R^2 score: -0.04858759690770387
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: -20910.18909508035
# Correlation coefficient: nan
# [73.08397143 73.08397143 73.49043841]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 468                  BCUTp-1l   -0.321204                    0.321204
# 476                  BCUTv-1l   -0.325136                    0.325136
# 520            ETA_dEpsilon_D    0.412783                    0.412783
#     molecular descriptor name  corr_value  absolute correlation value
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 468                  BCUTp-1l   -0.321204                    0.321204
# 476                  BCUTv-1l   -0.325136                    0.325136
# 520            ETA_dEpsilon_D    0.412783                    0.412783
# Return the coefficient of determination of the prediction:
# -0.6133412557731179
# R^2 score: -0.048005987918787074
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: -29555.30235186734
# Correlation coefficient: nan
# [73.09526054 73.09526054 73.43679956]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:23: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:23: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:23: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:23: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 456                BCUTare-1l    0.345707                    0.345707
# 520            ETA_dEpsilon_D    0.412783                    0.412783
# 829                     NaaNH    0.386873                    0.386873
# 831                      NaaS   -0.343855                    0.343855
# 899                     SaaNH    0.359872                    0.359872
#     molecular descriptor name  corr_value  absolute correlation value
# 456                BCUTare-1l    0.345707                    0.345707
# 520            ETA_dEpsilon_D    0.412783                    0.412783
# 829                     NaaNH    0.386873                    0.386873
# 831                      NaaS   -0.343855                    0.343855
# 899                     SaaNH    0.359872                    0.359872
# Return the coefficient of determination of the prediction:
# -0.609085190282078
# R^2 score: -0.04796942153222039
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: -46795.75579413227
# Correlation coefficient: nan
# [73.09857524 73.09857524 73.36964677]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 456                BCUTare-1l    0.345707                    0.345707
# 520            ETA_dEpsilon_D    0.412783                    0.412783
# 829                     NaaNH    0.386873                    0.386873
# 831                      NaaS   -0.343855                    0.343855
# 899                     SaaNH    0.359872                    0.359872
#     molecular descriptor name  corr_value  absolute correlation value
# 456                BCUTare-1l    0.345707                    0.345707
# 520            ETA_dEpsilon_D    0.412783                    0.412783
# 829                     NaaNH    0.386873                    0.386873
# 831                      NaaS   -0.343855                    0.343855
# 899                     SaaNH    0.359872                    0.359872
# Return the coefficient of determination of the prediction:
# -0.31123048728301894
# R^2 score: -0.06014367912575902
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: -176.71193161431344
# Correlation coefficient: nan
# [73.2394181  71.98819062 68.79366399]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#      molecular descriptor name  corr_value  absolute correlation value
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 829                      NaaNH    0.386873                    0.386873
# 899                      SaaNH    0.359872                    0.359872
# 1126                   n6HRing    0.362058                    0.362058
# 1128                  n6aHRing    0.362527                    0.362527
#      molecular descriptor name  corr_value  absolute correlation value
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 829                      NaaNH    0.386873                    0.386873
# 899                      SaaNH    0.359872                    0.359872
# 1126                   n6HRing    0.362058                    0.362058
# 1128                  n6aHRing    0.362527                    0.362527
# Return the coefficient of determination of the prediction:
# -0.3300482558137039
# R^2 score: -0.06161062368312398
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: -224.8968711724572
# Correlation coefficient: nan
# [73.03092352 71.99134467 69.08012765]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#      molecular descriptor name  corr_value  absolute correlation value
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 829                      NaaNH    0.386873                    0.386873
# 1126                   n6HRing    0.362058                    0.362058
# 1128                  n6aHRing    0.362527                    0.362527
# 1160                    nHBDon    0.394681                    0.394681
#      molecular descriptor name  corr_value  absolute correlation value
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 829                      NaaNH    0.386873                    0.386873
# 1126                   n6HRing    0.362058                    0.362058
# 1128                  n6aHRing    0.362527                    0.362527
# 1160                    nHBDon    0.394681                    0.394681
# Return the coefficient of determination of the prediction:
# -0.42201347115889387
# R^2 score: -0.06044619865367329
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: -441.80192704005094
# Correlation coefficient: nan
# [73.78411498 71.99958321 70.77658469]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:23: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:23: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:23: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:23: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#           molecular descriptor name  corr_value  absolute correlation value
# 520                  ETA_dEpsilon_D    0.412783                    0.412783
# 829                           NaaNH    0.386873                    0.386873
# 1160                         nHBDon    0.394681                    0.394681
# 1182  Aktywność cytoprotekcyjna [%]    1.000000                    1.000000
#      molecular descriptor name  corr_value  absolute correlation value
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 829                      NaaNH    0.386873                    0.386873
# 1160                    nHBDon    0.394681                    0.394681
# Return the coefficient of determination of the prediction:
# -0.34764478640277785
# R^2 score: -0.06685106961687204
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: -141.5261519039418
# Correlation coefficient: nan
# [74.87469844 71.99927651 69.69463574]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#           molecular descriptor name  corr_value  absolute correlation value
# 520                  ETA_dEpsilon_D    0.412783                    0.412783
# 829                           NaaNH    0.386873                    0.386873
# 1160                         nHBDon    0.394681                    0.394681
# 1182  Aktywność cytoprotekcyjna [%]    1.000000                    1.000000
#      molecular descriptor name  corr_value  absolute correlation value
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 829                      NaaNH    0.386873                    0.386873
# 1160                    nHBDon    0.394681                    0.394681
# Return the coefficient of determination of the prediction:
# -0.34764478640277785
# R^2 score: -0.06685106961687204
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: -141.5261519039418
# Correlation coefficient: nan
# [74.87469844 71.99927651 69.69463574]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am not doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#           molecular descriptor name  corr_value  absolute correlation value
# 520                  ETA_dEpsilon_D    0.412783                    0.412783
# 1160                         nHBDon    0.394681                    0.394681
# 1182  Aktywność cytoprotekcyjna [%]    1.000000                    1.000000
#      molecular descriptor name  corr_value  absolute correlation value
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 1160                    nHBDon    0.394681                    0.394681
# Return the coefficient of determination of the prediction:
# -0.38009488667182567
# R^2 score: -0.0708994008179642
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: -207.48714705223136
# Correlation coefficient: nan
# [74.51546819 71.99882613 70.19187363]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:23: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:23: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:23: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))

# %%
df_without_standarization = pd.DataFrame(data=first_list, columns=["Correlation threshold"])

# %%
df_without_standarization['Training data R^2 score'] = second_list
df_without_standarization['Test data R^2 score'] = third_list
df_without_standarization['Number of features'] = f_list

# %%
df_without_standarization
# Out:
#     Correlation threshold  Training data R^2 score  Test data R^2 score  \
# 0                    0.25                -0.061076             0.000000
# 1                    0.26                -0.061076             0.000000
# 2                    0.27                -0.061055             0.000000
# 3                    0.28                -0.058329             0.000000
# 4                    0.29                -0.048628       -177537.242015
# 5                    0.30                -0.048738        -20292.407957
# 6                    0.31                -0.048588        -20910.189095
# 7                    0.32                -0.048006        -29555.302352
# 8                    0.33                -0.047969        -46795.755794
# 9                    0.34                -0.060144          -176.711932
# 10                   0.35                -0.061611          -224.896871
# 11                   0.36                -0.060446          -441.801927
# 12                   0.37                -0.066851          -141.526152
# 13                   0.38                -0.066851          -141.526152
# 14                   0.39                -0.070899          -207.487147
#
#     Number of features
# 0                   46
# 1                   38
# 2                   30
# 3                   28
# 4                   26
# 5                   21
# 6                   20
# 7                   15
# 8                   12
# 9                    9
# 10                   6
# 11                   5
# 12                   3
# 13                   3
# 14                   2

# %%
step = 0.01
initial_step = 0.25
last_step = 0.4
first_list = [x / 100.0 for x in range(int(initial_step*100), int(last_step*100), int(step*100))]
second_list = []
third_list = []
f_list = []
for i in first_list:
    without_standarization, train_r2, test_r2, _, h_ = prepare_data_and_create_model(molecular_descriptors_df, i, True)
    second_list.append(train_r2)
    third_list.append(test_r2)
    f_list.append(len(h_))
# Out:
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 45                   AATS4are    0.257682                    0.257682
# 53                    AATS4se    0.265626                    0.265626
# 85                     AATS7s    0.254720                    0.254720
# 101                   AATSC0c    0.264307                    0.264307
# 125                   AATSC2c    0.260430                    0.260430
#     molecular descriptor name  corr_value  absolute correlation value
# 45                   AATS4are    0.257682                    0.257682
# 53                    AATS4se    0.265626                    0.265626
# 85                     AATS7s    0.254720                    0.254720
# 101                   AATSC0c    0.264307                    0.264307
# 125                   AATSC2c    0.260430                    0.260430
# Return the coefficient of determination of the prediction:
# -0.46188092014352256
# R^2 score: -0.02692462391894801
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: -3833.27196129285
# Correlation coefficient: nan
# [72.25207281 71.38220384 71.31988254]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:23: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 53                    AATS4se    0.265626                    0.265626
# 101                   AATSC0c    0.264307                    0.264307
# 125                   AATSC2c    0.260430                    0.260430
# 137                   AATSC3c   -0.319623                    0.319623
# 367                    ATSC3c   -0.273000                    0.273000
#     molecular descriptor name  corr_value  absolute correlation value
# 53                    AATS4se    0.265626                    0.265626
# 101                   AATSC0c    0.264307                    0.264307
# 125                   AATSC2c    0.260430                    0.260430
# 137                   AATSC3c   -0.319623                    0.319623
# 367                    ATSC3c   -0.273000                    0.273000
# Return the coefficient of determination of the prediction:
# -0.46318245404900416
# R^2 score: -0.023380949593668765
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: -5143.2180103281635
# Correlation coefficient: nan
# [72.15632744 71.58321553 71.26853179]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 367                    ATSC3c   -0.273000                    0.273000
# 392                    ATSC5d    0.291862                    0.291862
# 401                    ATSC6Z    0.282292                    0.282292
# 407                    ATSC6m    0.277298                    0.277298
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 367                    ATSC3c   -0.273000                    0.273000
# 392                    ATSC5d    0.291862                    0.291862
# 401                    ATSC6Z    0.282292                    0.282292
# 407                    ATSC6m    0.277298                    0.277298
# Return the coefficient of determination of the prediction:
# -0.43920890195728646
# R^2 score: -0.019219273889333977
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: -1953.9950179819025
# Correlation coefficient: nan
# [72.30695646 71.71701446 70.86648475]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:23: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:23: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 392                    ATSC5d    0.291862                    0.291862
# 401                    ATSC6Z    0.282292                    0.282292
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 392                    ATSC5d    0.291862                    0.291862
# 401                    ATSC6Z    0.282292                    0.282292
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# Return the coefficient of determination of the prediction:
# -0.42231215491351803
# R^2 score: -0.01568209521551811
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: -1339.4529341616642
# Correlation coefficient: nan
# [72.3002838  71.7026064  70.58737675]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 392                    ATSC5d    0.291862                    0.291862
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 461                 BCUTdv-1h    0.298210                    0.298210
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 392                    ATSC5d    0.291862                    0.291862
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 461                 BCUTdv-1h    0.298210                    0.298210
# Return the coefficient of determination of the prediction:
# -0.41465512810113303
# R^2 score: -0.008905250324749536
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: -1102.3583003838094
# Correlation coefficient: nan
# [72.37758198 71.66467326 70.485307  ]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:23: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:23: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 468                  BCUTp-1l   -0.321204                    0.321204
# 469                 BCUTpe-1h    0.317690                    0.317690
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 468                  BCUTp-1l   -0.321204                    0.321204
# 469                 BCUTpe-1h    0.317690                    0.317690
# Return the coefficient of determination of the prediction:
# -0.41141217317435985
# R^2 score: -0.017861861002116397
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: -1579.4389351172774
# Correlation coefficient: nan
# [71.87575287 71.54447525 70.35876629]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 468                  BCUTp-1l   -0.321204                    0.321204
# 469                 BCUTpe-1h    0.317690                    0.317690
#     molecular descriptor name  corr_value  absolute correlation value
# 137                   AATSC3c   -0.319623                    0.319623
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 468                  BCUTp-1l   -0.321204                    0.321204
# 469                 BCUTpe-1h    0.317690                    0.317690
# Return the coefficient of determination of the prediction:
# -0.39004925518734535
# R^2 score: -0.02119760613393895
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: -858.9795902162801
# Correlation coefficient: nan
# [72.01352746 71.64755899 69.99922046]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:23: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:23: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 468                  BCUTp-1l   -0.321204                    0.321204
# 476                  BCUTv-1l   -0.325136                    0.325136
# 520            ETA_dEpsilon_D    0.412783                    0.412783
#     molecular descriptor name  corr_value  absolute correlation value
# 455                BCUTare-1h    0.323770                    0.323770
# 456                BCUTare-1l    0.345707                    0.345707
# 468                  BCUTp-1l   -0.321204                    0.321204
# 476                  BCUTv-1l   -0.325136                    0.325136
# 520            ETA_dEpsilon_D    0.412783                    0.412783
# Return the coefficient of determination of the prediction:
# -0.36402926068461183
# R^2 score: -0.014453307534357585
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: -575.2087541136068
# Correlation coefficient: nan
# [71.99693563 71.58374104 69.5698063 ]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 456                BCUTare-1l    0.345707                    0.345707
# 520            ETA_dEpsilon_D    0.412783                    0.412783
# 829                     NaaNH    0.386873                    0.386873
# 831                      NaaS   -0.343855                    0.343855
# 899                     SaaNH    0.359872                    0.359872
#     molecular descriptor name  corr_value  absolute correlation value
# 456                BCUTare-1l    0.345707                    0.345707
# 520            ETA_dEpsilon_D    0.412783                    0.412783
# 829                     NaaNH    0.386873                    0.386873
# 831                      NaaS   -0.343855                    0.343855
# 899                     SaaNH    0.359872                    0.359872
# Return the coefficient of determination of the prediction:
# -0.4077083979488305
# R^2 score: -0.05012335560264036
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: -1428.9241300113017
# Correlation coefficient: nan
# [71.79542063 71.60985385 70.26111976]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:23: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:23: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#     molecular descriptor name  corr_value  absolute correlation value
# 456                BCUTare-1l    0.345707                    0.345707
# 520            ETA_dEpsilon_D    0.412783                    0.412783
# 829                     NaaNH    0.386873                    0.386873
# 831                      NaaS   -0.343855                    0.343855
# 899                     SaaNH    0.359872                    0.359872
#     molecular descriptor name  corr_value  absolute correlation value
# 456                BCUTare-1l    0.345707                    0.345707
# 520            ETA_dEpsilon_D    0.412783                    0.412783
# 829                     NaaNH    0.386873                    0.386873
# 831                      NaaS   -0.343855                    0.343855
# 899                     SaaNH    0.359872                    0.359872
# Return the coefficient of determination of the prediction:
# -0.3881572168838645
# R^2 score: -0.044205260742371966
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: -1351.5817789952218
# Correlation coefficient: nan
# [71.47839039 71.3403303  69.93324664]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#      molecular descriptor name  corr_value  absolute correlation value
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 829                      NaaNH    0.386873                    0.386873
# 899                      SaaNH    0.359872                    0.359872
# 1126                   n6HRing    0.362058                    0.362058
# 1128                  n6aHRing    0.362527                    0.362527
#      molecular descriptor name  corr_value  absolute correlation value
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 829                      NaaNH    0.386873                    0.386873
# 899                      SaaNH    0.359872                    0.359872
# 1126                   n6HRing    0.362058                    0.362058
# 1128                  n6aHRing    0.362527                    0.362527
# Return the coefficient of determination of the prediction:
# -0.4284054660181422
# R^2 score: -0.04241285183790677
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: -7147.085638741272
# Correlation coefficient: nan
# [71.37209948 71.15260118 70.63712786]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:23: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:23: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#      molecular descriptor name  corr_value  absolute correlation value
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 829                      NaaNH    0.386873                    0.386873
# 1126                   n6HRing    0.362058                    0.362058
# 1128                  n6aHRing    0.362527                    0.362527
# 1160                    nHBDon    0.394681                    0.394681
#      molecular descriptor name  corr_value  absolute correlation value
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 829                      NaaNH    0.386873                    0.386873
# 1126                   n6HRing    0.362058                    0.362058
# 1128                  n6aHRing    0.362527                    0.362527
# 1160                    nHBDon    0.394681                    0.394681
# Return the coefficient of determination of the prediction:
# -0.43484057464745285
# R^2 score: -0.040666745277178284
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: -6739.500458399338
# Correlation coefficient: nan
# [71.57617552 71.03666997 70.82000685]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#           molecular descriptor name  corr_value  absolute correlation value
# 520                  ETA_dEpsilon_D    0.412783                    0.412783
# 829                           NaaNH    0.386873                    0.386873
# 1160                         nHBDon    0.394681                    0.394681
# 1182  Aktywność cytoprotekcyjna [%]    1.000000                    1.000000
#      molecular descriptor name  corr_value  absolute correlation value
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 829                      NaaNH    0.386873                    0.386873
# 1160                    nHBDon    0.394681                    0.394681
# Return the coefficient of determination of the prediction:
# -0.34590504004194966
# R^2 score: -0.04160677307013105
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: -312.45376082582
# Correlation coefficient: nan
# [73.05708324 70.30548638 69.81115964]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:23: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:23: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#           molecular descriptor name  corr_value  absolute correlation value
# 520                  ETA_dEpsilon_D    0.412783                    0.412783
# 829                           NaaNH    0.386873                    0.386873
# 1160                         nHBDon    0.394681                    0.394681
# 1182  Aktywność cytoprotekcyjna [%]    1.000000                    1.000000
#      molecular descriptor name  corr_value  absolute correlation value
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 829                      NaaNH    0.386873                    0.386873
# 1160                    nHBDon    0.394681                    0.394681
# Return the coefficient of determination of the prediction:
# -0.34590504004194966
# R^2 score: -0.04160677307013105
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: -312.45376082582
# Correlation coefficient: nan
# [73.05708324 70.30548638 69.81115964]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# I am doing standarization...
#   molecular descriptor name
# 0                    AATS0Z
# 1                  AATS0are
# 2                    AATS0d
# 3                   AATS0dv
# 4                    AATS0i
#   molecular descriptor name  corr_value
# 0                    AATS0Z   -0.105872
# 1                  AATS0are    0.160494
# 2                    AATS0d   -0.005044
# 3                   AATS0dv    0.121256
# 4                    AATS0i    0.140698
#   molecular descriptor name  corr_value  absolute correlation value
# 0                    AATS0Z   -0.105872                    0.105872
# 1                  AATS0are    0.160494                    0.160494
# 2                    AATS0d   -0.005044                    0.005044
# 3                   AATS0dv    0.121256                    0.121256
# 4                    AATS0i    0.140698                    0.140698
#           molecular descriptor name  corr_value  absolute correlation value
# 520                  ETA_dEpsilon_D    0.412783                    0.412783
# 1160                         nHBDon    0.394681                    0.394681
# 1182  Aktywność cytoprotekcyjna [%]    1.000000                    1.000000
#      molecular descriptor name  corr_value  absolute correlation value
# 520             ETA_dEpsilon_D    0.412783                    0.412783
# 1160                    nHBDon    0.394681                    0.394681
# Return the coefficient of determination of the prediction:
# -0.3619424606418715
# R^2 score: -0.04098783893304225
# Correlation coefficient: nan
# Test data - unseen during training:
# R^2 score: -333.91258942710346
# Correlation coefficient: nan
# [73.04762414 70.06000447 70.14107324]
# 0     81.0
# 5     60.0
# 14    28.0
# Name: Aktywność cytoprotekcyjna [%], dtype: float64
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:23: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\1179623727.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   to_be_returned['Aktywność cytoprotekcyjna [%]'] = dataframe['Aktywność cytoprotekcyjna [%]']
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(y, pred))
# C:\Users\aleks\AppData\Local\Temp\ipykernel_13172\3262070140.py:23: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_r2 = np.sqrt(r2_score(pred, test_data['Aktywność cytoprotekcyjna [%]']))

# %%
df_with_standarization = pd.DataFrame(data=first_list, columns=["Correlation threshold"])
df_with_standarization['Training data R^2 score'] = second_list
df_with_standarization['Test data R^2 score'] = third_list
df_with_standarization['Number of features'] = f_list

# %%
df_with_standarization
# Out:
#     Correlation threshold  Training data R^2 score  Test data R^2 score  \
# 0                    0.25                -0.026925         -3833.271961
# 1                    0.26                -0.023381         -5143.218010
# 2                    0.27                -0.019219         -1953.995018
# 3                    0.28                -0.015682         -1339.452934
# 4                    0.29                -0.008905         -1102.358300
# 5                    0.30                -0.017862         -1579.438935
# 6                    0.31                -0.021198          -858.979590
# 7                    0.32                -0.014453          -575.208754
# 8                    0.33                -0.050123         -1428.924130
# 9                    0.34                -0.044205         -1351.581779
# 10                   0.35                -0.042413         -7147.085639
# 11                   0.36                -0.040667         -6739.500458
# 12                   0.37                -0.041607          -312.453761
# 13                   0.38                -0.041607          -312.453761
# 14                   0.39                -0.040988          -333.912589
#
#     Number of features
# 0                   46
# 1                   38
# 2                   30
# 3                   28
# 4                   26
# 5                   21
# 6                   20
# 7                   15
# 8                   12
# 9                    9
# 10                   6
# 11                   5
# 12                   3
# 13                   3
# 14                   2

# %% [markdown]
# ## Plots

# %%
plt.plot(df_without_standarization['Correlation threshold'], df_without_standarization['Training data R^2 score'], label = "Training data R^2 score", marker='v')
plt.plot(df_without_standarization['Correlation threshold'], df_without_standarization['Test data R^2 score'], label = "Test data R^2 score", marker='D')
plt.legend()
plt.xlabel('Correlation threshold')
plt.ylabel('R^2 score')
#plt.ylim([0, 1])
plt.show()

# %%
plt.plot(df_without_standarization['Correlation threshold'], df_without_standarization['Number of features'], label = "Number of features", marker='.')
plt.legend()
plt.xlabel('Correlation threshold')
plt.ylabel('Number of features')
plt.show()

# %% [markdown]
# # sqrt(R^2)

# %%
break
# Out:
#   Cell In[34], line 1
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
df_without_standarization['train R value'] = [np.sqrt(x) for x in df_without_standarization['Training data R^2 score']]

# %%
df_without_standarization

# %%
xcz = []
for element in df_without_standarization['Test data R^2 score']:
    x = np.sqrt(element)
    try:
        if x > 0:
            xcz.append(x)
        else:
            xcz.append(0)
    except:
        pass

# %%
xcz

# %%
df_without_standarization['test R value'] = xcz

# %%
plt.plot(df_without_standarization['Correlation threshold'], df_without_standarization['train R value'], label = "train R value", marker='v')
plt.plot(df_without_standarization['Correlation threshold'], df_without_standarization['test R value'], label = "test R value", marker='D')
plt.legend()
plt.xlabel('Correlation threshold')
plt.ylabel('R score')
plt.ylim([0, 1])
plt.show()

# %%
plt.plot(df_without_standarization['Correlation threshold'], df_without_standarization['Number of features'], label = "Number of features", marker='.')
plt.legend()
plt.xlabel('Correlation threshold')
plt.ylabel('Number of features')
plt.show()

# %% [markdown]
# ## Final model

# %%
final_model = prepare_data_and_create_model(molecular_descriptors_df, 0.33, False)

# %%
final_model[0].get_params()

# %%
final_model[0].intercept_

# %%
final_model[0].coef_

# %% [markdown]
# ## Build equation

# %%
final_model[4]

# %%
names = list(final_model[4]['molecular descriptor name'])
print("The model's equation is: ")
for i in range(len(names)):
    print(str(final_model[0].coef_[i])+str(' * ')+str(names[i]))
    
print(str(final_model[0].intercept_))

# %% [markdown]
# ## Predict target feature

# %%
to_prediction = prepare_data('../Data/Proposed_structures_with_AI_caffeine_tanimoto_similarity_.xlsx')

# %%
predicted_activity = final_model[0].predict(to_prediction[final_model[4]['molecular descriptor name']])

# %%
smiles = pd.read_excel('../Data/Proposed_structures_with_AI_caffeine_tanimoto_similarity_.xlsx')
smiles = smiles['new_SMILES']
smiles = smiles.to_list()
save_to_df = pd.DataFrame(data=smiles, columns=['SMILES'])

# %%
print(len(smiles))
print(len(predicted_activity))

# %%
save_to_df.head()

# %%
save_to_df['Predicted activity'] = predicted_activity

# %%
save_to_df.head()

# %%
save_to_df.to_excel('../Data/Predicted_activity.xlsx')
